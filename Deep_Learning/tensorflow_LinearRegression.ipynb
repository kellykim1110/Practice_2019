# %%
import tensorflow as tf

# %%
x_data=[1,2,3,4,5]
y_data=[10,20,30,40,50]


X=tf.placeholder(tf.float32,name="X")
Y=tf.placeholder(tf.float32,name="Y")


W=tf.Variable(tf.random_normal([1],-1,1))
b=tf.Variable(tf.random_normal([1],-1,1))

# %%
print(W,b)
print(X,Y)
# Out:
# <tf.Variable 'Variable:0' shape=(1,) dtype=float32_ref> <tf.Variable 'Variable_1:0' shape=(1,) dtype=float32_ref>
# Tensor("X_1:0", dtype=float32) Tensor("Y_1:0", dtype=float32)

# %%
#define the score function
score=W*X+b

# %%
#define theloss function
loss=tf.reduce_mean(tf.square(score-Y))
loss
# Out:
# <tf.Tensor 'Mean:0' shape=() dtype=float32>

# %%
optimizer=tf.train.GradientDescentOptimizer(learning_rate=0.01)
optimizer=optimizer.minimize(loss)
optimizer
# Out:
# <tf.Operation 'GradientDescent_1' type=NoOp>

# %%
with tf.Session() as sess:
  sess.run(tf.global_variables_initializer())
  
  for step in range(100):
    _, loss_val=sess.run([optimizer,loss],feed_dict={X:x_data,Y:y_data})
    print(step, 'Loss = %-10.5f' % loss_val, 'W = %10.6f' % sess.run(W), 'B = %10.6f' % sess.run(b))  
    #10.5f : 전체 10칸에서 소수점 5자리까지
# Out:
# 0 Loss = 2039.49683 W =  -0.022721 B =  -1.360138
# 1 Loss = 1188.64807 W =   2.263886 B =  -0.731572
# 2 Loss = 692.81445  W =   4.009725 B =  -0.252774
# 3 Loss = 403.86633  W =   5.342752 B =   0.111698
# 4 Loss = 235.48080  W =   6.360645 B =   0.388899
# 5 Loss = 137.35316  W =   7.137969 B =   0.599482
# 6 Loss = 80.16838   W =   7.731647 B =   0.759215
# 7 Loss = 46.84309   W =   8.185132 B =   0.880132
# 8 Loss = 27.42191   W =   8.531595 B =   0.971421
# 9 Loss = 16.10337   W =   8.796359 B =   1.040097
# 10 Loss = 9.50665    W =   8.998755 B =   1.091513
# 11 Loss = 5.66158    W =   9.153538 B =   1.129758
# 12 Loss = 3.42005    W =   9.271974 B =   1.157951
# 13 Loss = 2.11298    W =   9.362662 B =   1.178473
# 14 Loss = 1.35048    W =   9.432168 B =   1.193144
# 15 Loss = 0.90532    W =   9.485502 B =   1.203351
# 16 Loss = 0.64511    W =   9.526490 B =   1.210154
# 17 Loss = 0.49268    W =   9.558053 B =   1.214361
# 18 Loss = 0.40306    W =   9.582419 B =   1.216591
# 19 Loss = 0.35005    W =   9.601292 B =   1.217314
# 20 Loss = 0.31838    W =   9.615969 B =   1.216890
# 21 Loss = 0.29916    W =   9.627442 B =   1.215594
# 22 Loss = 0.28719    W =   9.636470 B =   1.213636
# 23 Loss = 0.27945    W =   9.643628 B =   1.211175
# 24 Loss = 0.27418    W =   9.649360 B =   1.208334
# 25 Loss = 0.27036    W =   9.654000 B =   1.205205
# 26 Loss = 0.26739    W =   9.657808 B =   1.201861
# 27 Loss = 0.26492    W =   9.660979 B =   1.198356
# 28 Loss = 0.26274    W =   9.663663 B =   1.194730
# 29 Loss = 0.26074    W =   9.665974 B =   1.191015
# 30 Loss = 0.25884    W =   9.667998 B =   1.187237
# 31 Loss = 0.25702    W =   9.669805 B =   1.183412
# 32 Loss = 0.25524    W =   9.671443 B =   1.179556
# 33 Loss = 0.25349    W =   9.672953 B =   1.175678
# 34 Loss = 0.25176    W =   9.674362 B =   1.171787
# 35 Loss = 0.25006    W =   9.675695 B =   1.167890
# 36 Loss = 0.24836    W =   9.676969 B =   1.163990
# 37 Loss = 0.24668    W =   9.678196 B =   1.160092
# 38 Loss = 0.24502    W =   9.679387 B =   1.156199
# 39 Loss = 0.24336    W =   9.680550 B =   1.152312
# 40 Loss = 0.24172    W =   9.681690 B =   1.148432
# 41 Loss = 0.24009    W =   9.682813 B =   1.144562
# 42 Loss = 0.23847    W =   9.683920 B =   1.140702
# 43 Loss = 0.23686    W =   9.685016 B =   1.136853
# 44 Loss = 0.23526    W =   9.686101 B =   1.133015
# 45 Loss = 0.23367    W =   9.687178 B =   1.129189
# 46 Loss = 0.23209    W =   9.688248 B =   1.125374
# 47 Loss = 0.23052    W =   9.689311 B =   1.121572
# 48 Loss = 0.22897    W =   9.690369 B =   1.117782
# 49 Loss = 0.22742    W =   9.691421 B =   1.114004
# 50 Loss = 0.22589    W =   9.692468 B =   1.110239
# 51 Loss = 0.22436    W =   9.693510 B =   1.106486
# 52 Loss = 0.22285    W =   9.694549 B =   1.102746
# 53 Loss = 0.22134    W =   9.695583 B =   1.099018
# 54 Loss = 0.21985    W =   9.696614 B =   1.095302
# 55 Loss = 0.21836    W =   9.697641 B =   1.091600
# 56 Loss = 0.21689    W =   9.698665 B =   1.087909
# 57 Loss = 0.21543    W =   9.699684 B =   1.084231
# 58 Loss = 0.21397    W =   9.700700 B =   1.080565
# 59 Loss = 0.21253    W =   9.701712 B =   1.076912
# 60 Loss = 0.21109    W =   9.702721 B =   1.073271
# 61 Loss = 0.20967    W =   9.703726 B =   1.069643
# 62 Loss = 0.20825    W =   9.704727 B =   1.066026
# 63 Loss = 0.20685    W =   9.705726 B =   1.062422
# 64 Loss = 0.20545    W =   9.706720 B =   1.058830
# 65 Loss = 0.20406    W =   9.707712 B =   1.055250
# 66 Loss = 0.20269    W =   9.708700 B =   1.051682
# 67 Loss = 0.20132    W =   9.709685 B =   1.048127
# 68 Loss = 0.19996    W =   9.710667 B =   1.044583
# 69 Loss = 0.19861    W =   9.711645 B =   1.041051
# 70 Loss = 0.19727    W =   9.712620 B =   1.037532
# 71 Loss = 0.19594    W =   9.713592 B =   1.034024
# 72 Loss = 0.19461    W =   9.714560 B =   1.030528
# 73 Loss = 0.19330    W =   9.715525 B =   1.027044
# 74 Loss = 0.19200    W =   9.716487 B =   1.023571
# 75 Loss = 0.19070    W =   9.717445 B =   1.020111
# 76 Loss = 0.18941    W =   9.718401 B =   1.016662
# 77 Loss = 0.18813    W =   9.719353 B =   1.013224
# 78 Loss = 0.18686    W =   9.720302 B =   1.009799
# 79 Loss = 0.18560    W =   9.721248 B =   1.006385
# 80 Loss = 0.18435    W =   9.722190 B =   1.002982
# 81 Loss = 0.18310    W =   9.723129 B =   0.999591
# 82 Loss = 0.18187    W =   9.724066 B =   0.996212
# 83 Loss = 0.18064    W =   9.724998 B =   0.992843
# 84 Loss = 0.17942    W =   9.725928 B =   0.989487
# 85 Loss = 0.17821    W =   9.726855 B =   0.986141
# 86 Loss = 0.17701    W =   9.727778 B =   0.982807
# 87 Loss = 0.17581    W =   9.728699 B =   0.979484
# 88 Loss = 0.17463    W =   9.729616 B =   0.976173
# 89 Loss = 0.17345    W =   9.730530 B =   0.972872
# 90 Loss = 0.17228    W =   9.731441 B =   0.969583
# 91 Loss = 0.17111    W =   9.732348 B =   0.966305
# 92 Loss = 0.16996    W =   9.733253 B =   0.963038
# 93 Loss = 0.16881    W =   9.734156 B =   0.959782
# 94 Loss = 0.16767    W =   9.735055 B =   0.956537
# 95 Loss = 0.16654    W =   9.735950 B =   0.953303
# 96 Loss = 0.16541    W =   9.736843 B =   0.950080
# 97 Loss = 0.16430    W =   9.737733 B =   0.946868
# 98 Loss = 0.16319    W =   9.738620 B =   0.943666
# 99 Loss = 0.16209    W =   9.739504 B =   0.940476

# %%
with tf.Session() as sess:
  sess.run(tf.global_variables_initializer())
  
  for step in range(1001):
    _, loss_val=sess.run([optimizer,loss],feed_dict={X:x_data,Y:y_data})
    if step%100==0:
      print(step, 'Loss = %-10.5f' % loss_val, 'W = %10.6f' % sess.run(W), 'B = %10.6f' % sess.run(b))  
      #10.5f : 전체 10칸에서 소수점 5자리까지
      
    print('Y = {Weight} * X + {Bias}'.format(Weight = sess.run(W), Bias = sess.run(b)))
    print("X:5, Y:",sess.run(score,feed_dict={X:[5]}))
    print("X:2.5, Y:",sess.run(score,feed_dict={X:[2.5]}))
# Out:
# 0 Loss = 997.87305  W =   3.099366 B =  -1.350171
# Y = [3.099366] * X + [-1.350171]
# X:5, Y: [14.146659]
# X:2.5, Y: [6.398244]
# Y = [4.698516] * X + [-0.9091295]
# X:5, Y: [22.58345]
# X:2.5, Y: [10.837161]
# Y = [5.91939] * X + [-0.57285786]
# X:5, Y: [29.024094]
# X:2.5, Y: [14.225617]
# Y = [6.8514957] * X + [-0.3165641]
# X:5, Y: [33.940914]
# X:2.5, Y: [16.812174]
# Y = [7.5631604] * X + [-0.12132257]
# X:5, Y: [37.69448]
# X:2.5, Y: [18.78658]
# Y = [8.1065445] * X + [0.02731424]
# X:5, Y: [40.560036]
# X:2.5, Y: [20.293676]
# Y = [8.521466] * X + [0.14037529]
# X:5, Y: [42.747707]
# X:2.5, Y: [21.44404]
# Y = [8.838321] * X + [0.22627978]
# X:5, Y: [44.417885]
# X:2.5, Y: [22.322083]
# Y = [9.080314] * X + [0.29145494]
# X:5, Y: [45.693024]
# X:2.5, Y: [22.992239]
# Y = [9.265158] * X + [0.34080702]
# X:5, Y: [46.6666]
# X:2.5, Y: [23.503702]
# Y = [9.406375] * X + [0.37808138]
# X:5, Y: [47.409958]
# X:2.5, Y: [23.89402]
# Y = [9.514288] * X + [0.40613726]
# X:5, Y: [47.977577]
# X:2.5, Y: [24.191858]
# Y = [9.596776] * X + [0.42715725]
# X:5, Y: [48.411037]
# X:2.5, Y: [24.419096]
# Y = [9.659856] * X + [0.44280756]
# X:5, Y: [48.742085]
# X:2.5, Y: [24.592447]
# Y = [9.708119] * X + [0.45436007]
# X:5, Y: [48.994957]
# X:2.5, Y: [24.724659]
# Y = [9.745071] * X + [0.4627857]
# X:5, Y: [49.18814]
# X:2.5, Y: [24.825464]
# Y = [9.773389] * X + [0.4688257]
# X:5, Y: [49.33577]
# X:2.5, Y: [24.902298]
# Y = [9.795114] * X + [0.47304586]
# X:5, Y: [49.448612]
# X:2.5, Y: [24.960829]
# Y = [9.811806] * X + [0.47587812]
# X:5, Y: [49.53491]
# X:2.5, Y: [25.005392]
# Y = [9.824656] * X + [0.4776522]
# X:5, Y: [49.60093]
# X:2.5, Y: [25.03929]
# Y = [9.834572] * X + [0.4786198]
# X:5, Y: [49.651478]
# X:2.5, Y: [25.06505]
# Y = [9.842249] * X + [0.47897312]
# X:5, Y: [49.690216]
# X:2.5, Y: [25.084595]
# Y = [9.848216] * X + [0.47885874]
# X:5, Y: [49.71994]
# X:2.5, Y: [25.0994]
# Y = [9.852877] * X + [0.4783886]
# X:5, Y: [49.74277]
# X:2.5, Y: [25.110579]
# Y = [9.856541] * X + [0.47764823]
# X:5, Y: [49.760353]
# X:2.5, Y: [25.119]
# Y = [9.859443] * X + [0.4767028]
# X:5, Y: [49.77392]
# X:2.5, Y: [25.12531]
# Y = [9.861763] * X + [0.47560218]
# X:5, Y: [49.784416]
# X:2.5, Y: [25.13001]
# Y = [9.863639] * X + [0.47438437]
# X:5, Y: [49.79258]
# X:2.5, Y: [25.133482]
# Y = [9.865175] * X + [0.47307834]
# X:5, Y: [49.798954]
# X:2.5, Y: [25.136015]
# Y = [9.866452] * X + [0.47170627]
# X:5, Y: [49.803967]
# X:2.5, Y: [25.137836]
# Y = [9.867531] * X + [0.470285]
# X:5, Y: [49.807938]
# X:2.5, Y: [25.139112]
# Y = [9.868457] * X + [0.46882746]
# X:5, Y: [49.81111]
# X:2.5, Y: [25.13997]
# Y = [9.8692665] * X + [0.4673435]
# X:5, Y: [49.813675]
# X:2.5, Y: [25.14051]
# Y = [9.8699875] * X + [0.46584064]
# X:5, Y: [49.815777]
# X:2.5, Y: [25.14081]
# Y = [9.87064] * X + [0.4643246]
# X:5, Y: [49.817524]
# X:2.5, Y: [25.140924]
# Y = [9.87124] * X + [0.4627997]
# X:5, Y: [49.818996]
# X:2.5, Y: [25.140898]
# Y = [9.871799] * X + [0.46126932]
# X:5, Y: [49.820267]
# X:2.5, Y: [25.140768]
# Y = [9.872328] * X + [0.45973596]
# X:5, Y: [49.821377]
# X:2.5, Y: [25.140556]
# Y = [9.872831] * X + [0.45820156]
# X:5, Y: [49.82236]
# X:2.5, Y: [25.140282]
# Y = [9.873316] * X + [0.45666763]
# X:5, Y: [49.823246]
# X:2.5, Y: [25.139956]
# Y = [9.873786] * X + [0.45513535]
# X:5, Y: [49.824066]
# X:2.5, Y: [25.1396]
# Y = [9.874245] * X + [0.45360547]
# X:5, Y: [49.82483]
# X:2.5, Y: [25.139217]
# Y = [9.874695] * X + [0.45207867]
# X:5, Y: [49.825554]
# X:2.5, Y: [25.138815]
# Y = [9.875137] * X + [0.4505554]
# X:5, Y: [49.82624]
# X:2.5, Y: [25.1384]
# Y = [9.875574] * X + [0.44903606]
# X:5, Y: [49.826904]
# X:2.5, Y: [25.13797]
# Y = [9.876006] * X + [0.4475209]
# X:5, Y: [49.827553]
# X:2.5, Y: [25.137537]
# Y = [9.876433] * X + [0.4460101]
# X:5, Y: [49.82818]
# X:2.5, Y: [25.137094]
# Y = [9.876858] * X + [0.4445039]
# X:5, Y: [49.828793]
# X:2.5, Y: [25.136648]
# Y = [9.877279] * X + [0.44300237]
# X:5, Y: [49.8294]
# X:2.5, Y: [25.136202]
# Y = [9.877698] * X + [0.44150558]
# X:5, Y: [49.829994]
# X:2.5, Y: [25.13575]
# Y = [9.878114] * X + [0.4400136]
# X:5, Y: [49.83058]
# X:2.5, Y: [25.135298]
# Y = [9.878528] * X + [0.43852648]
# X:5, Y: [49.831165]
# X:2.5, Y: [25.134846]
# Y = [9.87894] * X + [0.4370443]
# X:5, Y: [49.831745]
# X:2.5, Y: [25.134394]
# Y = [9.87935] * X + [0.43556702]
# X:5, Y: [49.832314]
# X:2.5, Y: [25.133942]
# Y = [9.879759] * X + [0.4340947]
# X:5, Y: [49.83289]
# X:2.5, Y: [25.133493]
# Y = [9.880166] * X + [0.43262726]
# X:5, Y: [49.833458]
# X:2.5, Y: [25.133041]
# Y = [9.880572] * X + [0.43116474]
# X:5, Y: [49.834026]
# X:2.5, Y: [25.132595]
# Y = [9.880977] * X + [0.4297071]
# X:5, Y: [49.83459]
# X:2.5, Y: [25.132149]
# Y = [9.881379] * X + [0.42825437]
# X:5, Y: [49.835148]
# X:2.5, Y: [25.131702]
# Y = [9.881781] * X + [0.42680654]
# X:5, Y: [49.835712]
# X:2.5, Y: [25.13126]
# Y = [9.88218] * X + [0.42536354]
# X:5, Y: [49.836266]
# X:2.5, Y: [25.130814]
# Y = [9.882579] * X + [0.42392543]
# X:5, Y: [49.836823]
# X:2.5, Y: [25.130373]
# Y = [9.882976] * X + [0.42249218]
# X:5, Y: [49.83737]
# X:2.5, Y: [25.129932]
# Y = [9.883371] * X + [0.42106378]
# X:5, Y: [49.837917]
# X:2.5, Y: [25.129492]
# Y = [9.883766] * X + [0.41964024]
# X:5, Y: [49.83847]
# X:2.5, Y: [25.129055]
# Y = [9.884159] * X + [0.41822147]
# X:5, Y: [49.839016]
# X:2.5, Y: [25.12862]
# Y = [9.884551] * X + [0.4168075]
# X:5, Y: [49.839565]
# X:2.5, Y: [25.128185]
# Y = [9.884941] * X + [0.41539827]
# X:5, Y: [49.840103]
# X:2.5, Y: [25.12775]
# Y = [9.88533] * X + [0.41399384]
# X:5, Y: [49.840645]
# X:2.5, Y: [25.12732]
# Y = [9.885718] * X + [0.41259414]
# X:5, Y: [49.841187]
# X:2.5, Y: [25.12689]
# Y = [9.886105] * X + [0.41119915]
# X:5, Y: [49.84172]
# X:2.5, Y: [25.126461]
# Y = [9.88649] * X + [0.4098089]
# X:5, Y: [49.84226]
# X:2.5, Y: [25.126034]
# Y = [9.886873] * X + [0.40842333]
# X:5, Y: [49.84279]
# X:2.5, Y: [25.125605]
# Y = [9.887256] * X + [0.40704247]
# X:5, Y: [49.843323]
# X:2.5, Y: [25.125181]
# Y = [9.887637] * X + [0.4056663]
# X:5, Y: [49.843853]
# X:2.5, Y: [25.12476]
# Y = [9.888017] * X + [0.40429473]
# X:5, Y: [49.844376]
# X:2.5, Y: [25.124336]
# Y = [9.888395] * X + [0.40292785]
# X:5, Y: [49.844906]
# X:2.5, Y: [25.123917]
# Y = [9.888773] * X + [0.40156558]
# X:5, Y: [49.84543]
# X:2.5, Y: [25.123497]
# Y = [9.889149] * X + [0.4002079]
# X:5, Y: [49.84595]
# X:2.5, Y: [25.12308]
# Y = [9.8895235] * X + [0.39885482]
# X:5, Y: [49.84647]
# X:2.5, Y: [25.122663]
# Y = [9.889897] * X + [0.39750633]
# X:5, Y: [49.846992]
# X:2.5, Y: [25.12225]
# Y = [9.890269] * X + [0.39616236]
# X:5, Y: [49.84751]
# X:2.5, Y: [25.121836]
# Y = [9.89064] * X + [0.39482296]
# X:5, Y: [49.848022]
# X:2.5, Y: [25.121424]
# Y = [9.89101] * X + [0.39348808]
# X:5, Y: [49.84854]
# X:2.5, Y: [25.121014]
# Y = [9.891378] * X + [0.39215767]
# X:5, Y: [49.849052]
# X:2.5, Y: [25.120605]
# Y = [9.891746] * X + [0.3908318]
# X:5, Y: [49.84956]
# X:2.5, Y: [25.120195]
# Y = [9.892112] * X + [0.38951045]
# X:5, Y: [49.85007]
# X:2.5, Y: [25.119791]
# Y = [9.892476] * X + [0.38819352]
# X:5, Y: [49.850574]
# X:2.5, Y: [25.119383]
# Y = [9.892839] * X + [0.38688108]
# X:5, Y: [49.851078]
# X:2.5, Y: [25.118979]
# Y = [9.893202] * X + [0.3855731]
# X:5, Y: [49.851585]
# X:2.5, Y: [25.118578]
# Y = [9.893563] * X + [0.3842695]
# X:5, Y: [49.852085]
# X:2.5, Y: [25.118177]
# Y = [9.893923] * X + [0.3829703]
# X:5, Y: [49.85258]
# X:2.5, Y: [25.117777]
# Y = [9.894281] * X + [0.38167554]
# X:5, Y: [49.85308]
# X:2.5, Y: [25.117378]
# Y = [9.894639] * X + [0.38038516]
# X:5, Y: [49.85358]
# X:2.5, Y: [25.116982]
# Y = [9.894996] * X + [0.3790991]
# X:5, Y: [49.85408]
# X:2.5, Y: [25.116589]
# Y = [9.89535] * X + [0.37781736]
# X:5, Y: [49.854572]
# X:2.5, Y: [25.116194]
# Y = [9.895704] * X + [0.37653998]
# X:5, Y: [49.855064]
# X:2.5, Y: [25.1158]
# Y = [9.896057] * X + [0.3752669]
# X:5, Y: [49.855553]
# X:2.5, Y: [25.11541]
# Y = [9.896408] * X + [0.37399814]
# X:5, Y: [49.856037]
# X:2.5, Y: [25.115019]
# Y = [9.896758] * X + [0.37273368]
# X:5, Y: [49.856525]
# X:2.5, Y: [25.11463]
# 100 Loss = 0.02529    W =   9.897107 B =   0.371474
# Y = [9.897107] * X + [0.37147352]
# X:5, Y: [49.85701]
# X:2.5, Y: [25.11424]
# Y = [9.897455] * X + [0.37021762]
# X:5, Y: [49.85749]
# X:2.5, Y: [25.113855]
# Y = [9.897802] * X + [0.36896598]
# X:5, Y: [49.85798]
# X:2.5, Y: [25.113472]
# Y = [9.898148] * X + [0.36771852]
# X:5, Y: [49.858456]
# X:2.5, Y: [25.113087]
# Y = [9.898492] * X + [0.3664753]
# X:5, Y: [49.858932]
# X:2.5, Y: [25.112705]
# Y = [9.898835] * X + [0.3652363]
# X:5, Y: [49.859413]
# X:2.5, Y: [25.112324]
# Y = [9.899178] * X + [0.36400145]
# X:5, Y: [49.85989]
# X:2.5, Y: [25.111946]
# Y = [9.899518] * X + [0.36277077]
# X:5, Y: [49.86036]
# X:2.5, Y: [25.111565]
# Y = [9.8998575] * X + [0.36154428]
# X:5, Y: [49.860832]
# X:2.5, Y: [25.111187]
# Y = [9.900196] * X + [0.36032194]
# X:5, Y: [49.8613]
# X:2.5, Y: [25.110811]
# Y = [9.900534] * X + [0.35910374]
# X:5, Y: [49.861774]
# X:2.5, Y: [25.11044]
# Y = [9.90087] * X + [0.35788962]
# X:5, Y: [49.862244]
# X:2.5, Y: [25.110065]
# Y = [9.901205] * X + [0.35667962]
# X:5, Y: [49.862705]
# X:2.5, Y: [25.109694]
# Y = [9.901539] * X + [0.35547373]
# X:5, Y: [49.863167]
# X:2.5, Y: [25.109322]
# Y = [9.901872] * X + [0.35427192]
# X:5, Y: [49.86363]
# X:2.5, Y: [25.108952]
# Y = [9.902204] * X + [0.3530742]
# X:5, Y: [49.86409]
# X:2.5, Y: [25.108583]
# Y = [9.9025345] * X + [0.3518805]
# X:5, Y: [49.86455]
# X:2.5, Y: [25.108217]
# Y = [9.902864] * X + [0.3506908]
# X:5, Y: [49.86501]
# X:2.5, Y: [25.107851]
# Y = [9.9031925] * X + [0.34950516]
# X:5, Y: [49.865467]
# X:2.5, Y: [25.107485]
# Y = [9.90352] * X + [0.3483235]
# X:5, Y: [49.86592]
# X:2.5, Y: [25.107122]
# Y = [9.903846] * X + [0.34714583]
# X:5, Y: [49.866375]
# X:2.5, Y: [25.10676]
# Y = [9.904171] * X + [0.34597218]
# X:5, Y: [49.86683]
# X:2.5, Y: [25.1064]
# Y = [9.904495] * X + [0.34480247]
# X:5, Y: [49.86728]
# X:2.5, Y: [25.106041]
# Y = [9.904819] * X + [0.3436367]
# X:5, Y: [49.86773]
# X:2.5, Y: [25.105684]
# Y = [9.90514] * X + [0.34247485]
# X:5, Y: [49.868176]
# X:2.5, Y: [25.105324]
# Y = [9.90546] * X + [0.34131697]
# X:5, Y: [49.868618]
# X:2.5, Y: [25.104967]
# Y = [9.90578] * X + [0.34016302]
# X:5, Y: [49.869064]
# X:2.5, Y: [25.104612]
# Y = [9.906098] * X + [0.33901298]
# X:5, Y: [49.869503]
# X:2.5, Y: [25.104258]
# Y = [9.906416] * X + [0.33786684]
# X:5, Y: [49.86995]
# X:2.5, Y: [25.103909]
# Y = [9.906733] * X + [0.33672452]
# X:5, Y: [49.870384]
# X:2.5, Y: [25.103556]
# Y = [9.907048] * X + [0.3355861]
# X:5, Y: [49.870827]
# X:2.5, Y: [25.103207]
# Y = [9.907362] * X + [0.33445147]
# X:5, Y: [49.87126]
# X:2.5, Y: [25.102858]
# Y = [9.907676] * X + [0.33332074]
# X:5, Y: [49.8717]
# X:2.5, Y: [25.10251]
# Y = [9.907988] * X + [0.3321938]
# X:5, Y: [49.872135]
# X:2.5, Y: [25.102163]
# Y = [9.9082985] * X + [0.33107063]
# X:5, Y: [49.872562]
# X:2.5, Y: [25.101816]
# Y = [9.908608] * X + [0.32995132]
# X:5, Y: [49.872993]
# X:2.5, Y: [25.101473]
# Y = [9.908917] * X + [0.32883576]
# X:5, Y: [49.87342]
# X:2.5, Y: [25.10113]
# Y = [9.909225] * X + [0.327724]
# X:5, Y: [49.87385]
# X:2.5, Y: [25.100788]
# Y = [9.909533] * X + [0.326616]
# X:5, Y: [49.874275]
# X:2.5, Y: [25.100447]
# Y = [9.909839] * X + [0.32551172]
# X:5, Y: [49.874706]
# X:2.5, Y: [25.10011]
# Y = [9.910144] * X + [0.32441115]
# X:5, Y: [49.87513]
# X:2.5, Y: [25.099771]
# Y = [9.910447] * X + [0.3233143]
# X:5, Y: [49.87555]
# X:2.5, Y: [25.099432]
# Y = [9.910749] * X + [0.3222212]
# X:5, Y: [49.87597]
# X:2.5, Y: [25.099096]
# Y = [9.911052] * X + [0.3211318]
# X:5, Y: [49.876392]
# X:2.5, Y: [25.098763]
# Y = [9.911352] * X + [0.32004604]
# X:5, Y: [49.87681]
# X:2.5, Y: [25.098427]
# Y = [9.911652] * X + [0.31896397]
# X:5, Y: [49.87722]
# X:2.5, Y: [25.098093]
# Y = [9.91195] * X + [0.3178856]
# X:5, Y: [49.877636]
# X:2.5, Y: [25.097761]
# Y = [9.912248] * X + [0.31681088]
# X:5, Y: [49.878048]
# X:2.5, Y: [25.09743]
# Y = [9.912544] * X + [0.3157398]
# X:5, Y: [49.87846]
# X:2.5, Y: [25.097101]
# Y = [9.91284] * X + [0.31467235]
# X:5, Y: [49.878872]
# X:2.5, Y: [25.096773]
# Y = [9.913135] * X + [0.31360853]
# X:5, Y: [49.879284]
# X:2.5, Y: [25.096445]
# Y = [9.913428] * X + [0.31254828]
# X:5, Y: [49.879692]
# X:2.5, Y: [25.096119]
# Y = [9.913721] * X + [0.3114916]
# X:5, Y: [49.880096]
# X:2.5, Y: [25.095793]
# Y = [9.914013] * X + [0.3104385]
# X:5, Y: [49.880505]
# X:2.5, Y: [25.09547]
# Y = [9.914304] * X + [0.30938897]
# X:5, Y: [49.880905]
# X:2.5, Y: [25.095148]
# Y = [9.914594] * X + [0.30834296]
# X:5, Y: [49.88131]
# X:2.5, Y: [25.094828]
# Y = [9.914883] * X + [0.30730048]
# X:5, Y: [49.881714]
# X:2.5, Y: [25.094507]
# Y = [9.915171] * X + [0.3062615]
# X:5, Y: [49.882114]
# X:2.5, Y: [25.094187]
# Y = [9.915458] * X + [0.30522603]
# X:5, Y: [49.882515]
# X:2.5, Y: [25.09387]
# Y = [9.915744] * X + [0.30419406]
# X:5, Y: [49.882915]
# X:2.5, Y: [25.093554]
# Y = [9.916028] * X + [0.30316556]
# X:5, Y: [49.883305]
# X:2.5, Y: [25.093235]
# Y = [9.916312] * X + [0.30214056]
# X:5, Y: [49.8837]
# X:2.5, Y: [25.092922]
# Y = [9.916595] * X + [0.30111903]
# X:5, Y: [49.884098]
# X:2.5, Y: [25.092607]
# Y = [9.916877] * X + [0.30010092]
# X:5, Y: [49.884487]
# X:2.5, Y: [25.092293]
# Y = [9.917158] * X + [0.2990863]
# X:5, Y: [49.88488]
# X:2.5, Y: [25.091982]
# Y = [9.9174385] * X + [0.29807508]
# X:5, Y: [49.88527]
# X:2.5, Y: [25.091671]
# Y = [9.917718] * X + [0.29706725]
# X:5, Y: [49.885654]
# X:2.5, Y: [25.091362]
# Y = [9.917996] * X + [0.29606283]
# X:5, Y: [49.886044]
# X:2.5, Y: [25.091053]
# Y = [9.918274] * X + [0.2950618]
# X:5, Y: [49.886433]
# X:2.5, Y: [25.090746]
# Y = [9.91855] * X + [0.29406413]
# X:5, Y: [49.88681]
# X:2.5, Y: [25.090437]
# Y = [9.918825] * X + [0.2930699]
# X:5, Y: [49.887196]
# X:2.5, Y: [25.090132]
# Y = [9.9191] * X + [0.29207897]
# X:5, Y: [49.887577]
# X:2.5, Y: [25.089828]
# Y = [9.9193735] * X + [0.2910914]
# X:5, Y: [49.88796]
# X:2.5, Y: [25.089525]
# Y = [9.919646] * X + [0.29010716]
# X:5, Y: [49.88834]
# X:2.5, Y: [25.089224]
# Y = [9.919918] * X + [0.28912625]
# X:5, Y: [49.888718]
# X:2.5, Y: [25.08892]
# Y = [9.920189] * X + [0.28814864]
# X:5, Y: [49.88909]
# X:2.5, Y: [25.088621]
# Y = [9.920459] * X + [0.28717434]
# X:5, Y: [49.88947]
# X:2.5, Y: [25.088322]
# Y = [9.920728] * X + [0.28620332]
# X:5, Y: [49.88984]
# X:2.5, Y: [25.088022]
# Y = [9.920996] * X + [0.2852356]
# X:5, Y: [49.890217]
# X:2.5, Y: [25.087727]
# Y = [9.921263] * X + [0.28427115]
# X:5, Y: [49.890587]
# X:2.5, Y: [25.08743]
# Y = [9.921529] * X + [0.28330997]
# X:5, Y: [49.890953]
# X:2.5, Y: [25.087132]
# Y = [9.921794] * X + [0.28235203]
# X:5, Y: [49.891323]
# X:2.5, Y: [25.086838]
# Y = [9.922058] * X + [0.28139734]
# X:5, Y: [49.89169]
# X:2.5, Y: [25.086542]
# Y = [9.922321] * X + [0.2804459]
# X:5, Y: [49.89205]
# X:2.5, Y: [25.086248]
# Y = [9.922584] * X + [0.2794977]
# X:5, Y: [49.892418]
# X:2.5, Y: [25.085957]
# Y = [9.922845] * X + [0.27855274]
# X:5, Y: [49.892776]
# X:2.5, Y: [25.085665]
# Y = [9.923106] * X + [0.277611]
# X:5, Y: [49.893143]
# X:2.5, Y: [25.085377]
# Y = [9.923367] * X + [0.2766724]
# X:5, Y: [49.893505]
# X:2.5, Y: [25.085089]
# Y = [9.923626] * X + [0.27573696]
# X:5, Y: [49.893867]
# X:2.5, Y: [25.084803]
# Y = [9.923884] * X + [0.27480465]
# X:5, Y: [49.894226]
# X:2.5, Y: [25.084517]
# Y = [9.924142] * X + [0.2738755]
# X:5, Y: [49.894585]
# X:2.5, Y: [25.08423]
# Y = [9.924398] * X + [0.27294946]
# X:5, Y: [49.894943]
# X:2.5, Y: [25.083946]
# Y = [9.924654] * X + [0.27202657]
# X:5, Y: [49.895294]
# X:2.5, Y: [25.08366]
# Y = [9.924909] * X + [0.2711068]
# X:5, Y: [49.89565]
# X:2.5, Y: [25.083378]
# Y = [9.925162] * X + [0.27019015]
# X:5, Y: [49.896004]
# X:2.5, Y: [25.083096]
# Y = [9.925415] * X + [0.26927662]
# X:5, Y: [49.89635]
# X:2.5, Y: [25.082813]
# Y = [9.925667] * X + [0.2683662]
# X:5, Y: [49.8967]
# X:2.5, Y: [25.082533]
# Y = [9.925918] * X + [0.26745886]
# X:5, Y: [49.89705]
# X:2.5, Y: [25.082253]
# Y = [9.926168] * X + [0.26655462]
# X:5, Y: [49.8974]
# X:2.5, Y: [25.081976]
# Y = [9.926418] * X + [0.2656534]
# X:5, Y: [49.897743]
# X:2.5, Y: [25.0817]
# 200 Loss = 0.01285    W =   9.926667 B =   0.264755
# Y = [9.926667] * X + [0.26475525]
# X:5, Y: [49.89809]
# X:2.5, Y: [25.081423]
# Y = [9.926915] * X + [0.2638601]
# X:5, Y: [49.898434]
# X:2.5, Y: [25.081148]
# Y = [9.927162] * X + [0.262968]
# X:5, Y: [49.898777]
# X:2.5, Y: [25.080873]
# Y = [9.927408] * X + [0.26207894]
# X:5, Y: [49.899117]
# X:2.5, Y: [25.080599]
# Y = [9.927653] * X + [0.2611929]
# X:5, Y: [49.89946]
# X:2.5, Y: [25.080326]
# Y = [9.927898] * X + [0.26030985]
# X:5, Y: [49.899803]
# X:2.5, Y: [25.080055]
# Y = [9.928143] * X + [0.25942972]
# X:5, Y: [49.900143]
# X:2.5, Y: [25.079786]
# Y = [9.928386] * X + [0.25855258]
# X:5, Y: [49.900482]
# X:2.5, Y: [25.079517]
# Y = [9.928628] * X + [0.2576784]
# X:5, Y: [49.900818]
# X:2.5, Y: [25.079248]
# Y = [9.928869] * X + [0.25680715]
# X:5, Y: [49.901154]
# X:2.5, Y: [25.078981]
# Y = [9.92911] * X + [0.25593886]
# X:5, Y: [49.901485]
# X:2.5, Y: [25.078712]
# Y = [9.929349] * X + [0.25507352]
# X:5, Y: [49.901817]
# X:2.5, Y: [25.078445]
# Y = [9.929587] * X + [0.2542111]
# X:5, Y: [49.90215]
# X:2.5, Y: [25.07818]
# Y = [9.929826] * X + [0.25335163]
# X:5, Y: [49.90248]
# X:2.5, Y: [25.077915]
# Y = [9.930063] * X + [0.25249505]
# X:5, Y: [49.90281]
# X:2.5, Y: [25.077652]
# Y = [9.9303] * X + [0.25164136]
# X:5, Y: [49.903137]
# X:2.5, Y: [25.07739]
# Y = [9.930535] * X + [0.25079057]
# X:5, Y: [49.903465]
# X:2.5, Y: [25.077127]
# Y = [9.93077] * X + [0.24994265]
# X:5, Y: [49.903793]
# X:2.5, Y: [25.076868]
# Y = [9.931004] * X + [0.2490976]
# X:5, Y: [49.904114]
# X:2.5, Y: [25.076607]
# Y = [9.931237] * X + [0.24825545]
# X:5, Y: [49.90444]
# X:2.5, Y: [25.076347]
# Y = [9.93147] * X + [0.2474161]
# X:5, Y: [49.904766]
# X:2.5, Y: [25.07609]
# Y = [9.931702] * X + [0.24657957]
# X:5, Y: [49.905087]
# X:2.5, Y: [25.075834]
# Y = [9.931932] * X + [0.24574588]
# X:5, Y: [49.905407]
# X:2.5, Y: [25.075577]
# Y = [9.932162] * X + [0.24491501]
# X:5, Y: [49.905727]
# X:2.5, Y: [25.075321]
# Y = [9.932392] * X + [0.24408697]
# X:5, Y: [49.906048]
# X:2.5, Y: [25.075068]
# Y = [9.932621] * X + [0.2432617]
# X:5, Y: [49.90637]
# X:2.5, Y: [25.074814]
# Y = [9.932849] * X + [0.2424392]
# X:5, Y: [49.906685]
# X:2.5, Y: [25.074562]
# Y = [9.933076] * X + [0.24161947]
# X:5, Y: [49.906998]
# X:2.5, Y: [25.074308]
# Y = [9.933302] * X + [0.24080253]
# X:5, Y: [49.907314]
# X:2.5, Y: [25.074059]
# Y = [9.933527] * X + [0.23998834]
# X:5, Y: [49.907623]
# X:2.5, Y: [25.073805]
# Y = [9.933752] * X + [0.23917694]
# X:5, Y: [49.90794]
# X:2.5, Y: [25.073559]
# Y = [9.933976] * X + [0.23836826]
# X:5, Y: [49.90825]
# X:2.5, Y: [25.073309]
# Y = [9.934199] * X + [0.23756231]
# X:5, Y: [49.90856]
# X:2.5, Y: [25.073061]
# Y = [9.934422] * X + [0.2367591]
# X:5, Y: [49.908867]
# X:2.5, Y: [25.072813]
# Y = [9.934643] * X + [0.23595862]
# X:5, Y: [49.909172]
# X:2.5, Y: [25.072565]
# Y = [9.934864] * X + [0.23516089]
# X:5, Y: [49.90948]
# X:2.5, Y: [25.07232]
# Y = [9.935084] * X + [0.23436582]
# X:5, Y: [49.90979]
# X:2.5, Y: [25.072077]
# Y = [9.935304] * X + [0.23357344]
# X:5, Y: [49.91009]
# X:2.5, Y: [25.071833]
# Y = [9.935522] * X + [0.23278373]
# X:5, Y: [49.910397]
# X:2.5, Y: [25.07159]
# Y = [9.93574] * X + [0.23199672]
# X:5, Y: [49.9107]
# X:2.5, Y: [25.071348]
# Y = [9.935958] * X + [0.23121235]
# X:5, Y: [49.911003]
# X:2.5, Y: [25.071108]
# Y = [9.936174] * X + [0.23043062]
# X:5, Y: [49.9113]
# X:2.5, Y: [25.070866]
# Y = [9.93639] * X + [0.22965156]
# X:5, Y: [49.911602]
# X:2.5, Y: [25.070627]
# Y = [9.936605] * X + [0.22887512]
# X:5, Y: [49.911903]
# X:2.5, Y: [25.070389]
# Y = [9.93682] * X + [0.2281013]
# X:5, Y: [49.9122]
# X:2.5, Y: [25.070152]
# Y = [9.937034] * X + [0.22733007]
# X:5, Y: [49.9125]
# X:2.5, Y: [25.069914]
# Y = [9.937246] * X + [0.22656147]
# X:5, Y: [49.912796]
# X:2.5, Y: [25.069677]
# Y = [9.937458] * X + [0.22579545]
# X:5, Y: [49.913086]
# X:2.5, Y: [25.06944]
# Y = [9.93767] * X + [0.22503205]
# X:5, Y: [49.91338]
# X:2.5, Y: [25.069206]
# Y = [9.9378805] * X + [0.22427122]
# X:5, Y: [49.913673]
# X:2.5, Y: [25.068974]
# Y = [9.93809] * X + [0.22351298]
# X:5, Y: [49.913967]
# X:2.5, Y: [25.068739]
# Y = [9.938299] * X + [0.2227573]
# X:5, Y: [49.914253]
# X:2.5, Y: [25.068506]
# Y = [9.938508] * X + [0.2220042]
# X:5, Y: [49.914543]
# X:2.5, Y: [25.068274]
# Y = [9.938716] * X + [0.22125365]
# X:5, Y: [49.914833]
# X:2.5, Y: [25.068045]
# Y = [9.938923] * X + [0.22050563]
# X:5, Y: [49.91512]
# X:2.5, Y: [25.067812]
# Y = [9.93913] * X + [0.21976015]
# X:5, Y: [49.91541]
# X:2.5, Y: [25.067585]
# Y = [9.939336] * X + [0.21901715]
# X:5, Y: [49.915695]
# X:2.5, Y: [25.067356]
# Y = [9.939541] * X + [0.21827666]
# X:5, Y: [49.91598]
# X:2.5, Y: [25.06713]
# Y = [9.939745] * X + [0.21753867]
# X:5, Y: [49.91626]
# X:2.5, Y: [25.0669]
# Y = [9.939949] * X + [0.21680322]
# X:5, Y: [49.91655]
# X:2.5, Y: [25.066675]
# Y = [9.940152] * X + [0.2160702]
# X:5, Y: [49.916832]
# X:2.5, Y: [25.06645]
# Y = [9.940354] * X + [0.21533966]
# X:5, Y: [49.91711]
# X:2.5, Y: [25.066225]
# Y = [9.940556] * X + [0.2146116]
# X:5, Y: [49.91739]
# X:2.5, Y: [25.066]
# Y = [9.940757] * X + [0.21388605]
# X:5, Y: [49.91767]
# X:2.5, Y: [25.065779]
# Y = [9.940957] * X + [0.21316291]
# X:5, Y: [49.917946]
# X:2.5, Y: [25.065556]
# Y = [9.941156] * X + [0.21244223]
# X:5, Y: [49.91822]
# X:2.5, Y: [25.065332]
# Y = [9.941356] * X + [0.21172403]
# X:5, Y: [49.918503]
# X:2.5, Y: [25.065113]
# Y = [9.941554] * X + [0.21100822]
# X:5, Y: [49.91878]
# X:2.5, Y: [25.064894]
# Y = [9.9417515] * X + [0.2102948]
# X:5, Y: [49.919052]
# X:2.5, Y: [25.064672]
# Y = [9.941949] * X + [0.2095838]
# X:5, Y: [49.919327]
# X:2.5, Y: [25.064455]
# Y = [9.942145] * X + [0.2088752]
# X:5, Y: [49.9196]
# X:2.5, Y: [25.06424]
# Y = [9.942341] * X + [0.20816897]
# X:5, Y: [49.919872]
# X:2.5, Y: [25.06402]
# Y = [9.942535] * X + [0.20746516]
# X:5, Y: [49.920143]
# X:2.5, Y: [25.063803]
# Y = [9.94273] * X + [0.20676373]
# X:5, Y: [49.920414]
# X:2.5, Y: [25.06359]
# Y = [9.942924] * X + [0.20606466]
# X:5, Y: [49.920685]
# X:2.5, Y: [25.063374]
# Y = [9.943116] * X + [0.20536794]
# X:5, Y: [49.920948]
# X:2.5, Y: [25.063158]
# Y = [9.943309] * X + [0.2046736]
# X:5, Y: [49.92122]
# X:2.5, Y: [25.062946]
# Y = [9.9435005] * X + [0.2039816]
# X:5, Y: [49.921486]
# X:2.5, Y: [25.062733]
# Y = [9.943691] * X + [0.20329192]
# X:5, Y: [49.92175]
# X:2.5, Y: [25.062521]
# Y = [9.943882] * X + [0.20260459]
# X:5, Y: [49.922016]
# X:2.5, Y: [25.06231]
# Y = [9.944072] * X + [0.20191957]
# X:5, Y: [49.92228]
# X:2.5, Y: [25.0621]
# Y = [9.944261] * X + [0.20123687]
# X:5, Y: [49.92254]
# X:2.5, Y: [25.061888]
# Y = [9.944449] * X + [0.2005565]
# X:5, Y: [49.922806]
# X:2.5, Y: [25.06168]
# Y = [9.944637] * X + [0.1998784]
# X:5, Y: [49.923065]
# X:2.5, Y: [25.061472]
# Y = [9.944824] * X + [0.19920258]
# X:5, Y: [49.923325]
# X:2.5, Y: [25.061264]
# Y = [9.945011] * X + [0.19852906]
# X:5, Y: [49.923584]
# X:2.5, Y: [25.061056]
# Y = [9.945197] * X + [0.19785783]
# X:5, Y: [49.923843]
# X:2.5, Y: [25.06085]
# Y = [9.945382] * X + [0.19718885]
# X:5, Y: [49.9241]
# X:2.5, Y: [25.060644]
# Y = [9.945567] * X + [0.19652215]
# X:5, Y: [49.92436]
# X:2.5, Y: [25.06044]
# Y = [9.945751] * X + [0.19585769]
# X:5, Y: [49.924614]
# X:2.5, Y: [25.060236]
# Y = [9.945934] * X + [0.19519545]
# X:5, Y: [49.924866]
# X:2.5, Y: [25.060032]
# Y = [9.946117] * X + [0.1945355]
# X:5, Y: [49.92512]
# X:2.5, Y: [25.05983]
# Y = [9.9463] * X + [0.19387774]
# X:5, Y: [49.925377]
# X:2.5, Y: [25.059628]
# Y = [9.946481] * X + [0.19322221]
# X:5, Y: [49.925625]
# X:2.5, Y: [25.059423]
# Y = [9.946662] * X + [0.19256893]
# X:5, Y: [49.92588]
# X:2.5, Y: [25.059225]
# Y = [9.946842] * X + [0.19191782]
# X:5, Y: [49.92613]
# X:2.5, Y: [25.059023]
# Y = [9.9470215] * X + [0.19126894]
# X:5, Y: [49.926376]
# X:2.5, Y: [25.058823]
# Y = [9.947201] * X + [0.19062227]
# X:5, Y: [49.926624]
# X:2.5, Y: [25.058624]
# Y = [9.947379] * X + [0.1899778]
# X:5, Y: [49.926876]
# X:2.5, Y: [25.058426]
# Y = [9.9475565] * X + [0.18933548]
# X:5, Y: [49.927116]
# X:2.5, Y: [25.058226]
# 300 Loss = 0.00653    W =   9.947734 B =   0.188695
# Y = [9.947734] * X + [0.18869539]
# X:5, Y: [49.927364]
# X:2.5, Y: [25.058031]
# Y = [9.94791] * X + [0.18805745]
# X:5, Y: [49.92761]
# X:2.5, Y: [25.057833]
# Y = [9.948087] * X + [0.1874217]
# X:5, Y: [49.927853]
# X:2.5, Y: [25.057638]
# Y = [9.948262] * X + [0.18678807]
# X:5, Y: [49.928097]
# X:2.5, Y: [25.057444]
# Y = [9.948438] * X + [0.18615659]
# X:5, Y: [49.928345]
# X:2.5, Y: [25.057251]
# Y = [9.948612] * X + [0.18552719]
# X:5, Y: [49.92859]
# X:2.5, Y: [25.057058]
# Y = [9.948786] * X + [0.18489991]
# X:5, Y: [49.928825]
# X:2.5, Y: [25.056864]
# Y = [9.948959] * X + [0.18427478]
# X:5, Y: [49.929073]
# X:2.5, Y: [25.056673]
# Y = [9.949132] * X + [0.1836517]
# X:5, Y: [49.92931]
# X:2.5, Y: [25.05648]
# Y = [9.949304] * X + [0.18303075]
# X:5, Y: [49.929546]
# X:2.5, Y: [25.05629]
# Y = [9.949475] * X + [0.18241192]
# X:5, Y: [49.929787]
# X:2.5, Y: [25.056099]
# Y = [9.949646] * X + [0.18179518]
# X:5, Y: [49.930027]
# X:2.5, Y: [25.05591]
# Y = [9.949816] * X + [0.1811805]
# X:5, Y: [49.930256]
# X:2.5, Y: [25.05572]
# Y = [9.9499855] * X + [0.18056796]
# X:5, Y: [49.930496]
# X:2.5, Y: [25.055532]
# Y = [9.950154] * X + [0.17995746]
# X:5, Y: [49.93073]
# X:2.5, Y: [25.055344]
# Y = [9.950323] * X + [0.17934905]
# X:5, Y: [49.930965]
# X:2.5, Y: [25.055159]
# Y = [9.950491] * X + [0.17874268]
# X:5, Y: [49.9312]
# X:2.5, Y: [25.054972]
# Y = [9.950659] * X + [0.17813836]
# X:5, Y: [49.931435]
# X:2.5, Y: [25.054787]
# Y = [9.950826] * X + [0.17753606]
# X:5, Y: [49.931664]
# X:2.5, Y: [25.0546]
# Y = [9.950992] * X + [0.17693579]
# X:5, Y: [49.931896]
# X:2.5, Y: [25.054415]
# Y = [9.951158] * X + [0.17633757]
# X:5, Y: [49.932125]
# X:2.5, Y: [25.054232]
# Y = [9.951323] * X + [0.17574136]
# X:5, Y: [49.932358]
# X:2.5, Y: [25.054049]
# Y = [9.951487] * X + [0.17514716]
# X:5, Y: [49.93258]
# X:2.5, Y: [25.053864]
# Y = [9.951651] * X + [0.17455502]
# X:5, Y: [49.93281]
# X:2.5, Y: [25.053682]
# Y = [9.951814] * X + [0.17396486]
# X:5, Y: [49.933033]
# X:2.5, Y: [25.0535]
# Y = [9.951977] * X + [0.17337672]
# X:5, Y: [49.93326]
# X:2.5, Y: [25.053318]
# Y = [9.952139] * X + [0.17279057]
# X:5, Y: [49.933487]
# X:2.5, Y: [25.053139]
# Y = [9.952301] * X + [0.17220642]
# X:5, Y: [49.933712]
# X:2.5, Y: [25.05296]
# Y = [9.952462] * X + [0.17162421]
# X:5, Y: [49.933933]
# X:2.5, Y: [25.05278]
# Y = [9.952623] * X + [0.17104399]
# X:5, Y: [49.93416]
# X:2.5, Y: [25.0526]
# Y = [9.952784] * X + [0.17046572]
# X:5, Y: [49.934383]
# X:2.5, Y: [25.052423]
# Y = [9.952943] * X + [0.16988939]
# X:5, Y: [49.9346]
# X:2.5, Y: [25.052246]
# Y = [9.953102] * X + [0.16931504]
# X:5, Y: [49.934826]
# X:2.5, Y: [25.05207]
# Y = [9.95326] * X + [0.16874261]
# X:5, Y: [49.935047]
# X:2.5, Y: [25.051895]
# Y = [9.953419] * X + [0.16817212]
# X:5, Y: [49.935265]
# X:2.5, Y: [25.05172]
# Y = [9.953576] * X + [0.16760355]
# X:5, Y: [49.935482]
# X:2.5, Y: [25.051544]
# Y = [9.953733] * X + [0.16703692]
# X:5, Y: [49.935707]
# X:2.5, Y: [25.05137]
# Y = [9.95389] * X + [0.16647217]
# X:5, Y: [49.93592]
# X:2.5, Y: [25.051195]
# Y = [9.954045] * X + [0.16590934]
# X:5, Y: [49.936134]
# X:2.5, Y: [25.051022]
# Y = [9.954201] * X + [0.16534844]
# X:5, Y: [49.93635]
# X:2.5, Y: [25.05085]
# Y = [9.954355] * X + [0.16478944]
# X:5, Y: [49.936565]
# X:2.5, Y: [25.050676]
# Y = [9.95451] * X + [0.16423233]
# X:5, Y: [49.936783]
# X:2.5, Y: [25.050507]
# Y = [9.954663] * X + [0.16367708]
# X:5, Y: [49.936993]
# X:2.5, Y: [25.050335]
# Y = [9.954817] * X + [0.16312374]
# X:5, Y: [49.93721]
# X:2.5, Y: [25.050167]
# Y = [9.954969] * X + [0.16257225]
# X:5, Y: [49.93742]
# X:2.5, Y: [25.049997]
# Y = [9.955122] * X + [0.16202264]
# X:5, Y: [49.937634]
# X:2.5, Y: [25.04983]
# Y = [9.955274] * X + [0.16147485]
# X:5, Y: [49.937843]
# X:2.5, Y: [25.049658]
# Y = [9.955425] * X + [0.16092893]
# X:5, Y: [49.938057]
# X:2.5, Y: [25.049492]
# Y = [9.955576] * X + [0.16038483]
# X:5, Y: [49.938263]
# X:2.5, Y: [25.049324]
# Y = [9.955727] * X + [0.15984258]
# X:5, Y: [49.938477]
# X:2.5, Y: [25.04916]
# Y = [9.955876] * X + [0.15930212]
# X:5, Y: [49.938683]
# X:2.5, Y: [25.048992]
# Y = [9.956025] * X + [0.1587635]
# X:5, Y: [49.93889]
# X:2.5, Y: [25.048826]
# Y = [9.956174] * X + [0.15822671]
# X:5, Y: [49.939095]
# X:2.5, Y: [25.04866]
# Y = [9.956322] * X + [0.15769176]
# X:5, Y: [49.9393]
# X:2.5, Y: [25.048496]
# Y = [9.95647] * X + [0.15715861]
# X:5, Y: [49.939507]
# X:2.5, Y: [25.048332]
# Y = [9.956616] * X + [0.15662728]
# X:5, Y: [49.93971]
# X:2.5, Y: [25.048168]
# Y = [9.956763] * X + [0.15609774]
# X:5, Y: [49.939915]
# X:2.5, Y: [25.048006]
# Y = [9.956909] * X + [0.15557]
# X:5, Y: [49.940117]
# X:2.5, Y: [25.047842]
# Y = [9.957055] * X + [0.15504405]
# X:5, Y: [49.94032]
# X:2.5, Y: [25.047682]
# Y = [9.9572] * X + [0.15451986]
# X:5, Y: [49.940517]
# X:2.5, Y: [25.04752]
# Y = [9.957345] * X + [0.15399747]
# X:5, Y: [49.940723]
# X:2.5, Y: [25.04736]
# Y = [9.957489] * X + [0.1534768]
# X:5, Y: [49.94092]
# X:2.5, Y: [25.0472]
# Y = [9.957633] * X + [0.15295793]
# X:5, Y: [49.941124]
# X:2.5, Y: [25.04704]
# Y = [9.957776] * X + [0.15244079]
# X:5, Y: [49.94132]
# X:2.5, Y: [25.04688]
# Y = [9.957919] * X + [0.15192541]
# X:5, Y: [49.94152]
# X:2.5, Y: [25.046724]
# Y = [9.958061] * X + [0.15141177]
# X:5, Y: [49.94172]
# X:2.5, Y: [25.046564]
# Y = [9.958203] * X + [0.15089986]
# X:5, Y: [49.941914]
# X:2.5, Y: [25.046408]
# Y = [9.958344] * X + [0.15038967]
# X:5, Y: [49.942112]
# X:2.5, Y: [25.04625]
# Y = [9.958486] * X + [0.1498812]
# X:5, Y: [49.942307]
# X:2.5, Y: [25.046095]
# Y = [9.958626] * X + [0.14937446]
# X:5, Y: [49.942505]
# X:2.5, Y: [25.045938]
# Y = [9.958766] * X + [0.14886941]
# X:5, Y: [49.9427]
# X:2.5, Y: [25.045784]
# Y = [9.958905] * X + [0.14836608]
# X:5, Y: [49.94289]
# X:2.5, Y: [25.04563]
# Y = [9.959044] * X + [0.14786445]
# X:5, Y: [49.94309]
# X:2.5, Y: [25.045477]
# Y = [9.959183] * X + [0.14736448]
# X:5, Y: [49.94328]
# X:2.5, Y: [25.04532]
# Y = [9.959321] * X + [0.14686623]
# X:5, Y: [49.94347]
# X:2.5, Y: [25.045168]
# Y = [9.959458] * X + [0.14636965]
# X:5, Y: [49.94366]
# X:2.5, Y: [25.045015]
# Y = [9.959596] * X + [0.14587475]
# X:5, Y: [49.94385]
# X:2.5, Y: [25.044863]
# Y = [9.959732] * X + [0.14538153]
# X:5, Y: [49.944042]
# X:2.5, Y: [25.044712]
# Y = [9.959868] * X + [0.14488997]
# X:5, Y: [49.944233]
# X:2.5, Y: [25.044561]
# Y = [9.960004] * X + [0.14440006]
# X:5, Y: [49.94442]
# X:2.5, Y: [25.044409]
# Y = [9.960139] * X + [0.14391182]
# X:5, Y: [49.94461]
# X:2.5, Y: [25.04426]
# Y = [9.960274] * X + [0.14342523]
# X:5, Y: [49.944794]
# X:2.5, Y: [25.04411]
# Y = [9.960408] * X + [0.1429403]
# X:5, Y: [49.94498]
# X:2.5, Y: [25.04396]
# Y = [9.960542] * X + [0.142457]
# X:5, Y: [49.945164]
# X:2.5, Y: [25.04381]
# Y = [9.960675] * X + [0.14197536]
# X:5, Y: [49.94535]
# X:2.5, Y: [25.043663]
# Y = [9.960808] * X + [0.14149533]
# X:5, Y: [49.945534]
# X:2.5, Y: [25.043514]
# Y = [9.96094] * X + [0.14101696]
# X:5, Y: [49.94572]
# X:2.5, Y: [25.04337]
# Y = [9.961072] * X + [0.1405402]
# X:5, Y: [49.9459]
# X:2.5, Y: [25.04322]
# Y = [9.961204] * X + [0.14006506]
# X:5, Y: [49.946083]
# X:2.5, Y: [25.043074]
# Y = [9.961335] * X + [0.13959156]
# X:5, Y: [49.946266]
# X:2.5, Y: [25.042929]
# Y = [9.961466] * X + [0.13911963]
# X:5, Y: [49.946445]
# X:2.5, Y: [25.042784]
# Y = [9.9615965] * X + [0.1386493]
# X:5, Y: [49.946632]
# X:2.5, Y: [25.04264]
# Y = [9.961726] * X + [0.13818052]
# X:5, Y: [49.94681]
# X:2.5, Y: [25.042496]
# Y = [9.961856] * X + [0.13771336]
# X:5, Y: [49.946995]
# X:2.5, Y: [25.042353]
# Y = [9.961985] * X + [0.13724774]
# X:5, Y: [49.94717]
# X:2.5, Y: [25.042208]
# Y = [9.962113] * X + [0.1367837]
# X:5, Y: [49.94735]
# X:2.5, Y: [25.042067]
# Y = [9.962241] * X + [0.13632123]
# X:5, Y: [49.94753]
# X:2.5, Y: [25.041925]
# Y = [9.962369] * X + [0.13586032]
# X:5, Y: [49.947704]
# X:2.5, Y: [25.041782]
# Y = [9.962496] * X + [0.13540098]
# X:5, Y: [49.94788]
# X:2.5, Y: [25.04164]
# Y = [9.962623] * X + [0.1349432]
# X:5, Y: [49.94806]
# X:2.5, Y: [25.0415]
# 400 Loss = 0.00331    W =   9.962749 B =   0.134487
# Y = [9.962749] * X + [0.13448697]
# X:5, Y: [49.94823]
# X:2.5, Y: [25.041359]
# Y = [9.962874] * X + [0.13403232]
# X:5, Y: [49.948406]
# X:2.5, Y: [25.04122]
# Y = [9.963] * X + [0.1335792]
# X:5, Y: [49.94858]
# X:2.5, Y: [25.04108]
# Y = [9.963125] * X + [0.13312759]
# X:5, Y: [49.948757]
# X:2.5, Y: [25.040941]
# Y = [9.96325] * X + [0.13267751]
# X:5, Y: [49.94893]
# X:2.5, Y: [25.040802]
# Y = [9.963374] * X + [0.13222894]
# X:5, Y: [49.9491]
# X:2.5, Y: [25.040665]
# Y = [9.963498] * X + [0.13178192]
# X:5, Y: [49.949272]
# X:2.5, Y: [25.040527]
# Y = [9.963621] * X + [0.13133639]
# X:5, Y: [49.949444]
# X:2.5, Y: [25.04039]
# Y = [9.963744] * X + [0.1308924]
# X:5, Y: [49.949615]
# X:2.5, Y: [25.040253]
# Y = [9.963867] * X + [0.13044989]
# X:5, Y: [49.949787]
# X:2.5, Y: [25.040117]
# Y = [9.963989] * X + [0.13000886]
# X:5, Y: [49.949955]
# X:2.5, Y: [25.039982]
# Y = [9.964111] * X + [0.12956934]
# X:5, Y: [49.950127]
# X:2.5, Y: [25.039848]
# Y = [9.964232] * X + [0.12913126]
# X:5, Y: [49.950294]
# X:2.5, Y: [25.039713]
# Y = [9.964354] * X + [0.12869468]
# X:5, Y: [49.950466]
# X:2.5, Y: [25.03958]
# Y = [9.964474] * X + [0.12825955]
# X:5, Y: [49.950626]
# X:2.5, Y: [25.039444]
# Y = [9.964594] * X + [0.12782596]
# X:5, Y: [49.950794]
# X:2.5, Y: [25.03931]
# Y = [9.964714] * X + [0.12739381]
# X:5, Y: [49.950966]
# X:2.5, Y: [25.039179]
# Y = [9.964833] * X + [0.12696308]
# X:5, Y: [49.95113]
# X:2.5, Y: [25.039045]
# Y = [9.964952] * X + [0.12653382]
# X:5, Y: [49.951294]
# X:2.5, Y: [25.038914]
# Y = [9.965071] * X + [0.12610601]
# X:5, Y: [49.95146]
# X:2.5, Y: [25.038784]
# Y = [9.965189] * X + [0.12567963]
# X:5, Y: [49.951622]
# X:2.5, Y: [25.03865]
# Y = [9.965306] * X + [0.1252547]
# X:5, Y: [49.951786]
# X:2.5, Y: [25.03852]
# Y = [9.965424] * X + [0.12483122]
# X:5, Y: [49.95195]
# X:2.5, Y: [25.038391]
# Y = [9.965541] * X + [0.12440917]
# X:5, Y: [49.952114]
# X:2.5, Y: [25.038261]
# Y = [9.965657] * X + [0.12398854]
# X:5, Y: [49.952274]
# X:2.5, Y: [25.038132]
# Y = [9.965774] * X + [0.12356932]
# X:5, Y: [49.95244]
# X:2.5, Y: [25.038004]
# Y = [9.965889] * X + [0.12315152]
# X:5, Y: [49.952595]
# X:2.5, Y: [25.037874]
# Y = [9.966004] * X + [0.12273516]
# X:5, Y: [49.952755]
# X:2.5, Y: [25.037746]
# Y = [9.96612] * X + [0.1223202]
# X:5, Y: [49.95292]
# X:2.5, Y: [25.037619]
# Y = [9.966234] * X + [0.1219066]
# X:5, Y: [49.953075]
# X:2.5, Y: [25.03749]
# Y = [9.966349] * X + [0.12149443]
# X:5, Y: [49.953236]
# X:2.5, Y: [25.037365]
# Y = [9.966462] * X + [0.12108363]
# X:5, Y: [49.953392]
# X:2.5, Y: [25.03724]
# Y = [9.966576] * X + [0.12067424]
# X:5, Y: [49.953552]
# X:2.5, Y: [25.037113]
# Y = [9.966688] * X + [0.12026621]
# X:5, Y: [49.95371]
# X:2.5, Y: [25.036987]
# Y = [9.966801] * X + [0.1198596]
# X:5, Y: [49.95386]
# X:2.5, Y: [25.036861]
# Y = [9.966913] * X + [0.11945438]
# X:5, Y: [49.954018]
# X:2.5, Y: [25.036736]
# Y = [9.967025] * X + [0.11905052]
# X:5, Y: [49.954174]
# X:2.5, Y: [25.036613]
# Y = [9.967136] * X + [0.11864802]
# X:5, Y: [49.95433]
# X:2.5, Y: [25.03649]
# Y = [9.967247] * X + [0.11824688]
# X:5, Y: [49.954483]
# X:2.5, Y: [25.036364]
# Y = [9.967358] * X + [0.11784711]
# X:5, Y: [49.954636]
# X:2.5, Y: [25.036242]
# Y = [9.967468] * X + [0.11744871]
# X:5, Y: [49.95479]
# X:2.5, Y: [25.03612]
# Y = [9.967578] * X + [0.11705165]
# X:5, Y: [49.95494]
# X:2.5, Y: [25.035997]
# Y = [9.967688] * X + [0.11665595]
# X:5, Y: [49.955097]
# X:2.5, Y: [25.035875]
# Y = [9.967797] * X + [0.11626156]
# X:5, Y: [49.955246]
# X:2.5, Y: [25.035755]
# Y = [9.967906] * X + [0.1158685]
# X:5, Y: [49.9554]
# X:2.5, Y: [25.035633]
# Y = [9.968015] * X + [0.11547679]
# X:5, Y: [49.95555]
# X:2.5, Y: [25.035513]
# Y = [9.9681225] * X + [0.11508635]
# X:5, Y: [49.9557]
# X:2.5, Y: [25.035393]
# Y = [9.96823] * X + [0.11469728]
# X:5, Y: [49.95585]
# X:2.5, Y: [25.035273]
# Y = [9.968338] * X + [0.11430953]
# X:5, Y: [49.956]
# X:2.5, Y: [25.035154]
# Y = [9.968445] * X + [0.11392305]
# X:5, Y: [49.956146]
# X:2.5, Y: [25.035034]
# Y = [9.968552] * X + [0.11353792]
# X:5, Y: [49.956295]
# X:2.5, Y: [25.034918]
# Y = [9.968658] * X + [0.11315406]
# X:5, Y: [49.956448]
# X:2.5, Y: [25.0348]
# Y = [9.968764] * X + [0.11277147]
# X:5, Y: [49.956593]
# X:2.5, Y: [25.034683]
# Y = [9.96887] * X + [0.11239019]
# X:5, Y: [49.95674]
# X:2.5, Y: [25.034567]
# Y = [9.968975] * X + [0.11201018]
# X:5, Y: [49.956886]
# X:2.5, Y: [25.034449]
# Y = [9.96908] * X + [0.11163146]
# X:5, Y: [49.95703]
# X:2.5, Y: [25.03433]
# Y = [9.969185] * X + [0.11125403]
# X:5, Y: [49.95718]
# X:2.5, Y: [25.034216]
# Y = [9.969289] * X + [0.11087785]
# X:5, Y: [49.95732]
# X:2.5, Y: [25.0341]
# Y = [9.969393] * X + [0.11050296]
# X:5, Y: [49.957466]
# X:2.5, Y: [25.033983]
# Y = [9.969496] * X + [0.11012933]
# X:5, Y: [49.95761]
# X:2.5, Y: [25.033869]
# Y = [9.969599] * X + [0.10975699]
# X:5, Y: [49.95775]
# X:2.5, Y: [25.033752]
# Y = [9.969702] * X + [0.10938594]
# X:5, Y: [49.957897]
# X:2.5, Y: [25.033642]
# Y = [9.969804] * X + [0.1090161]
# X:5, Y: [49.958035]
# X:2.5, Y: [25.033525]
# Y = [9.969906] * X + [0.10864754]
# X:5, Y: [49.958176]
# X:2.5, Y: [25.033413]
# Y = [9.970008] * X + [0.10828024]
# X:5, Y: [49.95832]
# X:2.5, Y: [25.0333]
# Y = [9.970109] * X + [0.10791416]
# X:5, Y: [49.958458]
# X:2.5, Y: [25.033186]
# Y = [9.97021] * X + [0.10754935]
# X:5, Y: [49.9586]
# X:2.5, Y: [25.033075]
# Y = [9.970311] * X + [0.10718577]
# X:5, Y: [49.95874]
# X:2.5, Y: [25.032963]
# Y = [9.970411] * X + [0.10682339]
# X:5, Y: [49.95888]
# X:2.5, Y: [25.032852]
# Y = [9.970511] * X + [0.10646225]
# X:5, Y: [49.95902]
# X:2.5, Y: [25.032742]
# Y = [9.970612] * X + [0.10610233]
# X:5, Y: [49.95916]
# X:2.5, Y: [25.03263]
# Y = [9.970711] * X + [0.10574359]
# X:5, Y: [49.959297]
# X:2.5, Y: [25.03252]
# Y = [9.97081] * X + [0.10538608]
# X:5, Y: [49.959435]
# X:2.5, Y: [25.032412]
# Y = [9.970908] * X + [0.10502977]
# X:5, Y: [49.95957]
# X:2.5, Y: [25.0323]
# Y = [9.971006] * X + [0.10467467]
# X:5, Y: [49.95971]
# X:2.5, Y: [25.032192]
# Y = [9.971105] * X + [0.10432078]
# X:5, Y: [49.959843]
# X:2.5, Y: [25.032082]
# Y = [9.971203] * X + [0.10396809]
# X:5, Y: [49.959984]
# X:2.5, Y: [25.031975]
# Y = [9.9713] * X + [0.10361655]
# X:5, Y: [49.960114]
# X:2.5, Y: [25.031866]
# Y = [9.971397] * X + [0.10326623]
# X:5, Y: [49.960255]
# X:2.5, Y: [25.03176]
# Y = [9.971494] * X + [0.10291706]
# X:5, Y: [49.960384]
# X:2.5, Y: [25.03165]
# Y = [9.97159] * X + [0.1025691]
# X:5, Y: [49.960518]
# X:2.5, Y: [25.031544]
# Y = [9.971686] * X + [0.10222232]
# X:5, Y: [49.960655]
# X:2.5, Y: [25.031439]
# Y = [9.971782] * X + [0.10187668]
# X:5, Y: [49.960785]
# X:2.5, Y: [25.031332]
# Y = [9.971877] * X + [0.10153226]
# X:5, Y: [49.96092]
# X:2.5, Y: [25.031225]
# Y = [9.971972] * X + [0.10118899]
# X:5, Y: [49.961052]
# X:2.5, Y: [25.03112]
# Y = [9.972067] * X + [0.10084687]
# X:5, Y: [49.96118]
# X:2.5, Y: [25.031015]
# Y = [9.972161] * X + [0.10050592]
# X:5, Y: [49.96131]
# X:2.5, Y: [25.030909]
# Y = [9.972256] * X + [0.10016613]
# X:5, Y: [49.961445]
# X:2.5, Y: [25.030806]
# Y = [9.972349] * X + [0.09982746]
# X:5, Y: [49.961575]
# X:2.5, Y: [25.0307]
# Y = [9.972443] * X + [0.09948996]
# X:5, Y: [49.961704]
# X:2.5, Y: [25.030596]
# Y = [9.972536] * X + [0.0991536]
# X:5, Y: [49.961834]
# X:2.5, Y: [25.030493]
# Y = [9.972629] * X + [0.09881835]
# X:5, Y: [49.961964]
# X:2.5, Y: [25.03039]
# Y = [9.972721] * X + [0.09848426]
# X:5, Y: [49.96209]
# X:2.5, Y: [25.030287]
# Y = [9.972814] * X + [0.09815132]
# X:5, Y: [49.96222]
# X:2.5, Y: [25.030186]
# Y = [9.972905] * X + [0.09781946]
# X:5, Y: [49.962345]
# X:2.5, Y: [25.030083]
# Y = [9.972997] * X + [0.09748875]
# X:5, Y: [49.96247]
# X:2.5, Y: [25.02998]
# Y = [9.973088] * X + [0.09715918]
# X:5, Y: [49.9626]
# X:2.5, Y: [25.029879]
# Y = [9.973179] * X + [0.0968307]
# X:5, Y: [49.962727]
# X:2.5, Y: [25.029778]
# Y = [9.973269] * X + [0.09650335]
# X:5, Y: [49.962852]
# X:2.5, Y: [25.029678]
# Y = [9.97336] * X + [0.0961771]
# X:5, Y: [49.962975]
# X:2.5, Y: [25.029575]
# 500 Loss = 0.00168    W =   9.973451 B =   0.095852
# Y = [9.973451] * X + [0.09585197]
# X:5, Y: [49.963104]
# X:2.5, Y: [25.029478]
# Y = [9.97354] * X + [0.09552789]
# X:5, Y: [49.96323]
# X:2.5, Y: [25.029379]
# Y = [9.97363] * X + [0.09520493]
# X:5, Y: [49.963352]
# X:2.5, Y: [25.02928]
# Y = [9.973719] * X + [0.09488304]
# X:5, Y: [49.963474]
# X:2.5, Y: [25.029179]
# Y = [9.973807] * X + [0.09456227]
# X:5, Y: [49.9636]
# X:2.5, Y: [25.029081]
# Y = [9.973896] * X + [0.09424258]
# X:5, Y: [49.963722]
# X:2.5, Y: [25.028982]
# Y = [9.973985] * X + [0.09392397]
# X:5, Y: [49.96385]
# X:2.5, Y: [25.028885]
# Y = [9.974072] * X + [0.0936064]
# X:5, Y: [49.963966]
# X:2.5, Y: [25.028788]
# Y = [9.97416] * X + [0.09328993]
# X:5, Y: [49.96409]
# X:2.5, Y: [25.02869]
# Y = [9.974248] * X + [0.09297453]
# X:5, Y: [49.964214]
# X:2.5, Y: [25.028593]
# Y = [9.974335] * X + [0.09266016]
# X:5, Y: [49.964333]
# X:2.5, Y: [25.028498]
# Y = [9.9744215] * X + [0.09234688]
# X:5, Y: [49.964455]
# X:2.5, Y: [25.0284]
# Y = [9.974508] * X + [0.09203466]
# X:5, Y: [49.964577]
# X:2.5, Y: [25.028307]
# Y = [9.974594] * X + [0.09172347]
# X:5, Y: [49.964695]
# X:2.5, Y: [25.02821]
# Y = [9.97468] * X + [0.09141334]
# X:5, Y: [49.96481]
# X:2.5, Y: [25.028112]
# Y = [9.974766] * X + [0.0911043]
# X:5, Y: [49.96493]
# X:2.5, Y: [25.028019]
# Y = [9.974851] * X + [0.09079628]
# X:5, Y: [49.96505]
# X:2.5, Y: [25.027922]
# Y = [9.974936] * X + [0.09048931]
# X:5, Y: [49.965168]
# X:2.5, Y: [25.027828]
# Y = [9.97502] * X + [0.09018339]
# X:5, Y: [49.965286]
# X:2.5, Y: [25.027735]
# Y = [9.975105] * X + [0.0898785]
# X:5, Y: [49.965405]
# X:2.5, Y: [25.027641]
# Y = [9.975189] * X + [0.08957462]
# X:5, Y: [49.96552]
# X:2.5, Y: [25.027548]
# Y = [9.975273] * X + [0.08927178]
# X:5, Y: [49.965637]
# X:2.5, Y: [25.027454]
# Y = [9.975357] * X + [0.08896997]
# X:5, Y: [49.965755]
# X:2.5, Y: [25.027363]
# Y = [9.97544] * X + [0.08866914]
# X:5, Y: [49.96587]
# X:2.5, Y: [25.02727]
# Y = [9.975523] * X + [0.08836936]
# X:5, Y: [49.965984]
# X:2.5, Y: [25.027178]
# Y = [9.975606] * X + [0.0880706]
# X:5, Y: [49.9661]
# X:2.5, Y: [25.027084]
# Y = [9.975689] * X + [0.08777284]
# X:5, Y: [49.966217]
# X:2.5, Y: [25.026995]
# Y = [9.975771] * X + [0.08747605]
# X:5, Y: [49.966328]
# X:2.5, Y: [25.026903]
# Y = [9.975853] * X + [0.08718029]
# X:5, Y: [49.966446]
# X:2.5, Y: [25.026814]
# Y = [9.975934] * X + [0.08688549]
# X:5, Y: [49.966557]
# X:2.5, Y: [25.02672]
# Y = [9.976015] * X + [0.08659172]
# X:5, Y: [49.966667]
# X:2.5, Y: [25.026628]
# Y = [9.976096] * X + [0.08629897]
# X:5, Y: [49.96678]
# X:2.5, Y: [25.02654]
# Y = [9.976177] * X + [0.08600721]
# X:5, Y: [49.966892]
# X:2.5, Y: [25.026451]
# Y = [9.976258] * X + [0.08571643]
# X:5, Y: [49.967007]
# X:2.5, Y: [25.026361]
# Y = [9.976338] * X + [0.08542661]
# X:5, Y: [49.967117]
# X:2.5, Y: [25.026272]
# Y = [9.9764185] * X + [0.08513778]
# X:5, Y: [49.967228]
# X:2.5, Y: [25.026184]
# Y = [9.976499] * X + [0.08484992]
# X:5, Y: [49.967342]
# X:2.5, Y: [25.026096]
# Y = [9.976578] * X + [0.084563]
# X:5, Y: [49.967453]
# X:2.5, Y: [25.026007]
# Y = [9.976657] * X + [0.08427707]
# X:5, Y: [49.967564]
# X:2.5, Y: [25.025919]
# Y = [9.976736] * X + [0.08399212]
# X:5, Y: [49.967674]
# X:2.5, Y: [25.025833]
# Y = [9.976814] * X + [0.08370811]
# X:5, Y: [49.96778]
# X:2.5, Y: [25.025743]
# Y = [9.976892] * X + [0.08342508]
# X:5, Y: [49.967884]
# X:2.5, Y: [25.025656]
# Y = [9.976971] * X + [0.08314305]
# X:5, Y: [49.967995]
# X:2.5, Y: [25.02557]
# Y = [9.977049] * X + [0.08286196]
# X:5, Y: [49.96811]
# X:2.5, Y: [25.025486]
# Y = [9.977126] * X + [0.08258177]
# X:5, Y: [49.968212]
# X:2.5, Y: [25.025398]
# Y = [9.977203] * X + [0.08230257]
# X:5, Y: [49.96832]
# X:2.5, Y: [25.02531]
# Y = [9.977281] * X + [0.08202433]
# X:5, Y: [49.968426]
# X:2.5, Y: [25.025225]
# Y = [9.977358] * X + [0.08174702]
# X:5, Y: [49.968533]
# X:2.5, Y: [25.02514]
# Y = [9.977434] * X + [0.08147063]
# X:5, Y: [49.96864]
# X:2.5, Y: [25.025055]
# Y = [9.97751] * X + [0.08119518]
# X:5, Y: [49.968746]
# X:2.5, Y: [25.024971]
# Y = [9.977587] * X + [0.08092065]
# X:5, Y: [49.968853]
# X:2.5, Y: [25.024887]
# Y = [9.977662] * X + [0.08064704]
# X:5, Y: [49.968956]
# X:2.5, Y: [25.024801]
# Y = [9.977737] * X + [0.08037437]
# X:5, Y: [49.969063]
# X:2.5, Y: [25.024717]
# Y = [9.977813] * X + [0.08010264]
# X:5, Y: [49.969166]
# X:2.5, Y: [25.024635]
# Y = [9.977888] * X + [0.07983183]
# X:5, Y: [49.969273]
# X:2.5, Y: [25.024553]
# Y = [9.9779625] * X + [0.07956191]
# X:5, Y: [49.969376]
# X:2.5, Y: [25.024467]
# Y = [9.978037] * X + [0.07929292]
# X:5, Y: [49.969475]
# X:2.5, Y: [25.024384]
# Y = [9.978111] * X + [0.07902486]
# X:5, Y: [49.96958]
# X:2.5, Y: [25.024303]
# Y = [9.978186] * X + [0.07875768]
# X:5, Y: [49.96969]
# X:2.5, Y: [25.024223]
# Y = [9.978259] * X + [0.07849137]
# X:5, Y: [49.969788]
# X:2.5, Y: [25.02414]
# Y = [9.9783325] * X + [0.07822601]
# X:5, Y: [49.969887]
# X:2.5, Y: [25.024057]
# Y = [9.978406] * X + [0.07796155]
# X:5, Y: [49.96999]
# X:2.5, Y: [25.023975]
# Y = [9.978479] * X + [0.07769797]
# X:5, Y: [49.970093]
# X:2.5, Y: [25.023895]
# Y = [9.978552] * X + [0.07743526]
# X:5, Y: [49.970196]
# X:2.5, Y: [25.023815]
# Y = [9.978624] * X + [0.07717345]
# X:5, Y: [49.970295]
# X:2.5, Y: [25.023733]
# Y = [9.978697] * X + [0.07691251]
# X:5, Y: [49.970398]
# X:2.5, Y: [25.023655]
# Y = [9.978768] * X + [0.07665245]
# X:5, Y: [49.970493]
# X:2.5, Y: [25.023573]
# Y = [9.97884] * X + [0.0763933]
# X:5, Y: [49.970592]
# X:2.5, Y: [25.023493]
# Y = [9.978911] * X + [0.07613505]
# X:5, Y: [49.97069]
# X:2.5, Y: [25.023415]
# Y = [9.978983] * X + [0.07587767]
# X:5, Y: [49.97079]
# X:2.5, Y: [25.023335]
# Y = [9.979054] * X + [0.07562114]
# X:5, Y: [49.970894]
# X:2.5, Y: [25.023256]
# Y = [9.979125] * X + [0.07536544]
# X:5, Y: [49.970993]
# X:2.5, Y: [25.023178]
# Y = [9.979196] * X + [0.07511062]
# X:5, Y: [49.97109]
# X:2.5, Y: [25.0231]
# Y = [9.979266] * X + [0.07485666]
# X:5, Y: [49.971188]
# X:2.5, Y: [25.023022]
# Y = [9.979336] * X + [0.07460357]
# X:5, Y: [49.971283]
# X:2.5, Y: [25.022943]
# Y = [9.979405] * X + [0.07435135]
# X:5, Y: [49.97138]
# X:2.5, Y: [25.022865]
# Y = [9.979475] * X + [0.07409998]
# X:5, Y: [49.971478]
# X:2.5, Y: [25.022789]
# Y = [9.979545] * X + [0.07384946]
# X:5, Y: [49.971573]
# X:2.5, Y: [25.02271]
# Y = [9.979614] * X + [0.07359981]
# X:5, Y: [49.971672]
# X:2.5, Y: [25.022635]
# Y = [9.979683] * X + [0.07335096]
# X:5, Y: [49.971767]
# X:2.5, Y: [25.022558]
# Y = [9.979752] * X + [0.07310295]
# X:5, Y: [49.971863]
# X:2.5, Y: [25.022482]
# Y = [9.97982] * X + [0.07285578]
# X:5, Y: [49.97196]
# X:2.5, Y: [25.022406]
# Y = [9.979888] * X + [0.07260945]
# X:5, Y: [49.97205]
# X:2.5, Y: [25.02233]
# Y = [9.979956] * X + [0.07236399]
# X:5, Y: [49.972145]
# X:2.5, Y: [25.022255]
# Y = [9.980023] * X + [0.07211935]
# X:5, Y: [49.972237]
# X:2.5, Y: [25.022177]
# Y = [9.980091] * X + [0.07187555]
# X:5, Y: [49.972332]
# X:2.5, Y: [25.022102]
# Y = [9.980159] * X + [0.07163257]
# X:5, Y: [49.972427]
# X:2.5, Y: [25.02203]
# Y = [9.980226] * X + [0.0713904]
# X:5, Y: [49.97252]
# X:2.5, Y: [25.021954]
# Y = [9.980292] * X + [0.07114904]
# X:5, Y: [49.97261]
# X:2.5, Y: [25.021881]
# Y = [9.980359] * X + [0.07090852]
# X:5, Y: [49.972702]
# X:2.5, Y: [25.021805]
# Y = [9.980426] * X + [0.07066882]
# X:5, Y: [49.972797]
# X:2.5, Y: [25.021734]
# Y = [9.980492] * X + [0.07042991]
# X:5, Y: [49.97289]
# X:2.5, Y: [25.02166]
# Y = [9.980557] * X + [0.07019179]
# X:5, Y: [49.972977]
# X:2.5, Y: [25.021585]
# Y = [9.980623] * X + [0.06995452]
# X:5, Y: [49.97307]
# X:2.5, Y: [25.021511]
# Y = [9.980689] * X + [0.06971806]
# X:5, Y: [49.973164]
# X:2.5, Y: [25.02144]
# Y = [9.980755] * X + [0.06948236]
# X:5, Y: [49.973255]
# X:2.5, Y: [25.02137]
# Y = [9.98082] * X + [0.06924743]
# X:5, Y: [49.973347]
# X:2.5, Y: [25.021297]
# Y = [9.980885] * X + [0.06901329]
# X:5, Y: [49.973434]
# X:2.5, Y: [25.021225]
# Y = [9.980949] * X + [0.06877996]
# X:5, Y: [49.973526]
# X:2.5, Y: [25.021154]
# Y = [9.981013] * X + [0.0685474]
# X:5, Y: [49.973614]
# X:2.5, Y: [25.021082]
# 600 Loss = 0.00086    W =   9.981077 B =   0.068316
# Y = [9.981077] * X + [0.06831565]
# X:5, Y: [49.973705]
# X:2.5, Y: [25.02101]
# Y = [9.981141] * X + [0.06808469]
# X:5, Y: [49.97379]
# X:2.5, Y: [25.020937]
# Y = [9.981205] * X + [0.06785452]
# X:5, Y: [49.97388]
# X:2.5, Y: [25.020866]
# Y = [9.981269] * X + [0.06762513]
# X:5, Y: [49.973972]
# X:2.5, Y: [25.020798]
# Y = [9.981332] * X + [0.06739648]
# X:5, Y: [49.974056]
# X:2.5, Y: [25.020725]
# Y = [9.981395] * X + [0.06716863]
# X:5, Y: [49.974144]
# X:2.5, Y: [25.020657]
# Y = [9.981458] * X + [0.06694157]
# X:5, Y: [49.974228]
# X:2.5, Y: [25.020586]
# Y = [9.981521] * X + [0.06671528]
# X:5, Y: [49.97432]
# X:2.5, Y: [25.020517]
# Y = [9.981584] * X + [0.06648973]
# X:5, Y: [49.974407]
# X:2.5, Y: [25.020449]
# Y = [9.981646] * X + [0.06626491]
# X:5, Y: [49.97449]
# X:2.5, Y: [25.020378]
# Y = [9.981708] * X + [0.06604088]
# X:5, Y: [49.97458]
# X:2.5, Y: [25.02031]
# Y = [9.98177] * X + [0.06581762]
# X:5, Y: [49.974667]
# X:2.5, Y: [25.02024]
# Y = [9.981832] * X + [0.06559509]
# X:5, Y: [49.97475]
# X:2.5, Y: [25.020174]
# Y = [9.981893] * X + [0.0653733]
# X:5, Y: [49.974834]
# X:2.5, Y: [25.020103]
# Y = [9.981954] * X + [0.06515229]
# X:5, Y: [49.97492]
# X:2.5, Y: [25.020037]
# Y = [9.982015] * X + [0.06493203]
# X:5, Y: [49.975006]
# X:2.5, Y: [25.019968]
# Y = [9.982076] * X + [0.0647125]
# X:5, Y: [49.97509]
# X:2.5, Y: [25.019901]
# Y = [9.982137] * X + [0.06449371]
# X:5, Y: [49.975178]
# X:2.5, Y: [25.019835]
# Y = [9.982197] * X + [0.06427562]
# X:5, Y: [49.975258]
# X:2.5, Y: [25.019768]
# Y = [9.982257] * X + [0.06405831]
# X:5, Y: [49.975346]
# X:2.5, Y: [25.019701]
# Y = [9.982317] * X + [0.06384172]
# X:5, Y: [49.975426]
# X:2.5, Y: [25.019632]
# Y = [9.982377] * X + [0.06362587]
# X:5, Y: [49.97551]
# X:2.5, Y: [25.019567]
# Y = [9.982436] * X + [0.06341074]
# X:5, Y: [49.975594]
# X:2.5, Y: [25.0195]
# Y = [9.982495] * X + [0.06319635]
# X:5, Y: [49.975674]
# X:2.5, Y: [25.019434]
# Y = [9.982554] * X + [0.06298269]
# X:5, Y: [49.975758]
# X:2.5, Y: [25.01937]
# Y = [9.982614] * X + [0.06276976]
# X:5, Y: [49.975838]
# X:2.5, Y: [25.019302]
# Y = [9.982673] * X + [0.06255755]
# X:5, Y: [49.97592]
# X:2.5, Y: [25.01924]
# Y = [9.982731] * X + [0.06234604]
# X:5, Y: [49.976]
# X:2.5, Y: [25.019173]
# Y = [9.982789] * X + [0.06213526]
# X:5, Y: [49.976078]
# X:2.5, Y: [25.019108]
# Y = [9.982847] * X + [0.06192522]
# X:5, Y: [49.976162]
# X:2.5, Y: [25.019045]
# Y = [9.982905] * X + [0.06171588]
# X:5, Y: [49.976242]
# X:2.5, Y: [25.01898]
# Y = [9.982964] * X + [0.06150725]
# X:5, Y: [49.976326]
# X:2.5, Y: [25.018917]
# Y = [9.983021] * X + [0.06129928]
# X:5, Y: [49.976402]
# X:2.5, Y: [25.01885]
# Y = [9.983078] * X + [0.06109206]
# X:5, Y: [49.976482]
# X:2.5, Y: [25.018787]
# Y = [9.983135] * X + [0.06088553]
# X:5, Y: [49.976562]
# ...
# X:5, Y: [49.98618]
# X:2.5, Y: [25.01104]
# Y = [9.990089] * X + [0.03577854]
# X:5, Y: [49.986225]
# X:2.5, Y: [25.011002]
# Y = [9.990123] * X + [0.03565761]
# X:5, Y: [49.98627]
# X:2.5, Y: [25.010965]
# Y = [9.990156] * X + [0.0355371]
# X:5, Y: [49.98632]
# X:2.5, Y: [25.01093]
# Y = [9.99019] * X + [0.03541697]
# X:5, Y: [49.986362]
# X:2.5, Y: [25.010891]
# Y = [9.990223] * X + [0.03529727]
# X:5, Y: [49.986412]
# X:2.5, Y: [25.010855]
# Y = [9.990256] * X + [0.03517794]
# X:5, Y: [49.98646]
# X:2.5, Y: [25.010818]
# Y = [9.990289] * X + [0.035059]
# X:5, Y: [49.986504]
# X:2.5, Y: [25.01078]
# Y = [9.990321] * X + [0.03494048]
# X:5, Y: [49.986546]
# X:2.5, Y: [25.010744]
# Y = [9.990355] * X + [0.03482241]
# X:5, Y: [49.986595]
# X:2.5, Y: [25.01071]
# 800 Loss = 0.00022    W =   9.990387 B =   0.034705
# Y = [9.990387] * X + [0.0347047]
# X:5, Y: [49.98664]
# X:2.5, Y: [25.010672]
# Y = [9.990419] * X + [0.03458738]
# X:5, Y: [49.986683]
# X:2.5, Y: [25.010635]
# Y = [9.990452] * X + [0.03447047]
# X:5, Y: [49.98673]
# X:2.5, Y: [25.0106]
# Y = [9.990484] * X + [0.03435396]
# X:5, Y: [49.98678]
# X:2.5, Y: [25.010565]
# Y = [9.990517] * X + [0.03423781]
# X:5, Y: [49.98682]
# X:2.5, Y: [25.010529]
# Y = [9.990549] * X + [0.03412207]
# X:5, Y: [49.986866]
# X:2.5, Y: [25.010494]
# Y = [9.990581] * X + [0.03400669]
# X:5, Y: [49.98691]
# X:2.5, Y: [25.010458]
# Y = [9.990612] * X + [0.03389171]
# X:5, Y: [49.986954]
# X:2.5, Y: [25.010422]
# Y = [9.9906435] * X + [0.03377714]
# X:5, Y: [49.98699]
# X:2.5, Y: [25.010386]
# Y = [9.990675] * X + [0.033663]
# X:5, Y: [49.98704]
# X:2.5, Y: [25.010351]
# Y = [9.990706] * X + [0.03354922]
# X:5, Y: [49.987083]
# X:2.5, Y: [25.010315]
# Y = [9.990738] * X + [0.03343585]
# X:5, Y: [49.987125]
# X:2.5, Y: [25.01028]
# Y = [9.990769] * X + [0.03332286]
# X:5, Y: [49.987167]
# X:2.5, Y: [25.010246]
# Y = [9.990801] * X + [0.03321024]
# X:5, Y: [49.987213]
# X:2.5, Y: [25.010212]
# Y = [9.990832] * X + [0.03309799]
# X:5, Y: [49.98726]
# X:2.5, Y: [25.01018]
# Y = [9.990864] * X + [0.0329861]
# X:5, Y: [49.987305]
# X:2.5, Y: [25.010145]
# Y = [9.990894] * X + [0.03287456]
# X:5, Y: [49.987347]
# X:2.5, Y: [25.01011]
# Y = [9.990925] * X + [0.0327634]
# X:5, Y: [49.98739]
# X:2.5, Y: [25.010075]
# Y = [9.990955] * X + [0.03265264]
# X:5, Y: [49.98743]
# X:2.5, Y: [25.01004]
# Y = [9.990986] * X + [0.03254227]
# X:5, Y: [49.987473]
# X:2.5, Y: [25.010008]
# Y = [9.991016] * X + [0.03243225]
# X:5, Y: [49.987514]
# X:2.5, Y: [25.009974]
# Y = [9.991047] * X + [0.03232262]
# X:5, Y: [49.987556]
# X:2.5, Y: [25.00994]
# Y = [9.991077] * X + [0.03221336]
# X:5, Y: [49.987602]
# X:2.5, Y: [25.009907]
# Y = [9.991108] * X + [0.03210444]
# X:5, Y: [49.987644]
# X:2.5, Y: [25.009874]
# Y = [9.9911375] * X + [0.03199587]
# X:5, Y: [49.987686]
# X:2.5, Y: [25.00984]
# Y = [9.991167] * X + [0.03188769]
# X:5, Y: [49.98772]
# X:2.5, Y: [25.009804]
# Y = [9.991198] * X + [0.03177993]
# X:5, Y: [49.987766]
# X:2.5, Y: [25.009773]
# Y = [9.991227] * X + [0.03167248]
# X:5, Y: [49.98781]
# X:2.5, Y: [25.009739]
# Y = [9.991257] * X + [0.03156539]
# X:5, Y: [49.98785]
# X:2.5, Y: [25.009706]
# Y = [9.991286] * X + [0.03145868]
# X:5, Y: [49.987892]
# X:2.5, Y: [25.009674]
# Y = [9.991316] * X + [0.03135232]
# X:5, Y: [49.987934]
# X:2.5, Y: [25.009644]
# Y = [9.991345] * X + [0.03124631]
# X:5, Y: [49.987972]
# X:2.5, Y: [25.00961]
# Y = [9.991375] * X + [0.03114066]
# X:5, Y: [49.988014]
# X:2.5, Y: [25.009579]
# Y = [9.991405] * X + [0.03103536]
# X:5, Y: [49.98806]
# X:2.5, Y: [25.009546]
# Y = [9.991433] * X + [0.03093038]
# X:5, Y: [49.988094]
# X:2.5, Y: [25.009512]
# Y = [9.991462] * X + [0.03082579]
# X:5, Y: [49.988136]
# X:2.5, Y: [25.009481]
# Y = [9.99149] * X + [0.03072156]
# X:5, Y: [49.98817]
# X:2.5, Y: [25.009447]
# Y = [9.991519] * X + [0.03061772]
# X:5, Y: [49.988213]
# X:2.5, Y: [25.009417]
# Y = [9.991548] * X + [0.03051423]
# X:5, Y: [49.98825]
# X:2.5, Y: [25.009382]
# Y = [9.991576] * X + [0.03041109]
# X:5, Y: [49.988293]
# X:2.5, Y: [25.009352]
# Y = [9.991605] * X + [0.03030831]
# X:5, Y: [49.98833]
# X:2.5, Y: [25.00932]
# Y = [9.991633] * X + [0.03020586]
# X:5, Y: [49.988373]
# X:2.5, Y: [25.00929]
# Y = [9.991662] * X + [0.03010374]
# X:5, Y: [49.988415]
# X:2.5, Y: [25.009258]
# Y = [9.99169] * X + [0.03000193]
# X:5, Y: [49.988453]
# X:2.5, Y: [25.009228]
# Y = [9.991717] * X + [0.02990049]
# X:5, Y: [49.988487]
# X:2.5, Y: [25.009193]
# Y = [9.991746] * X + [0.02979946]
# X:5, Y: [49.98853]
# X:2.5, Y: [25.009163]
# Y = [9.991774] * X + [0.02969871]
# X:5, Y: [49.988567]
# X:2.5, Y: [25.009134]
# Y = [9.991801] * X + [0.02959832]
# X:5, Y: [49.988605]
# X:2.5, Y: [25.009102]
# Y = [9.991829] * X + [0.02949828]
# X:5, Y: [49.988644]
# X:2.5, Y: [25.009071]
# Y = [9.991857] * X + [0.02939857]
# X:5, Y: [49.98868]
# X:2.5, Y: [25.009039]
# Y = [9.991884] * X + [0.0292992]
# X:5, Y: [49.98872]
# X:2.5, Y: [25.009008]
# Y = [9.991912] * X + [0.02920016]
# X:5, Y: [49.98876]
# X:2.5, Y: [25.00898]
# Y = [9.99194] * X + [0.02910144]
# X:5, Y: [49.9888]
# X:2.5, Y: [25.008951]
# Y = [9.991966] * X + [0.02900302]
# X:5, Y: [49.988834]
# X:2.5, Y: [25.008919]
# Y = [9.991994] * X + [0.02890498]
# X:5, Y: [49.988873]
# X:2.5, Y: [25.00889]
# Y = [9.992021] * X + [0.02880725]
# X:5, Y: [49.98891]
# X:2.5, Y: [25.008858]
# Y = [9.992047] * X + [0.02870986]
# X:5, Y: [49.988945]
# X:2.5, Y: [25.008827]
# Y = [9.992074] * X + [0.02861283]
# X:5, Y: [49.988983]
# X:2.5, Y: [25.008797]
# Y = [9.992101] * X + [0.02851613]
# X:5, Y: [49.989017]
# X:2.5, Y: [25.008768]
# Y = [9.992127] * X + [0.02841977]
# X:5, Y: [49.989056]
# X:2.5, Y: [25.008738]
# Y = [9.992154] * X + [0.02832374]
# X:5, Y: [49.989094]
# X:2.5, Y: [25.008709]
# Y = [9.992181] * X + [0.02822801]
# X:5, Y: [49.989132]
# X:2.5, Y: [25.00868]
# Y = [9.992208] * X + [0.02813259]
# X:5, Y: [49.98917]
# X:2.5, Y: [25.008652]
# Y = [9.992234] * X + [0.02803747]
# X:5, Y: [49.98921]
# X:2.5, Y: [25.008623]
# Y = [9.99226] * X + [0.02794266]
# X:5, Y: [49.989243]
# X:2.5, Y: [25.008593]
# Y = [9.992287] * X + [0.02784821]
# X:5, Y: [49.98928]
# X:2.5, Y: [25.008564]
# Y = [9.992312] * X + [0.02775406]
# X:5, Y: [49.98932]
# X:2.5, Y: [25.008535]
# Y = [9.992338] * X + [0.02766022]
# X:5, Y: [49.989353]
# X:2.5, Y: [25.008507]
# Y = [9.992364] * X + [0.02756671]
# X:5, Y: [49.989384]
# X:2.5, Y: [25.008476]
# Y = [9.99239] * X + [0.02747355]
# X:5, Y: [49.98942]
# X:2.5, Y: [25.008448]
# Y = [9.992415] * X + [0.0273807]
# X:5, Y: [49.98946]
# X:2.5, Y: [25.008419]
# Y = [9.992441] * X + [0.02728816]
# X:5, Y: [49.98949]
# X:2.5, Y: [25.00839]
# Y = [9.992467] * X + [0.02719595]
# X:5, Y: [49.98953]
# X:2.5, Y: [25.008364]
# Y = [9.992493] * X + [0.02710401]
# X:5, Y: [49.989567]
# X:2.5, Y: [25.008335]
# Y = [9.992518] * X + [0.02701238]
# X:5, Y: [49.989605]
# X:2.5, Y: [25.008308]
# Y = [9.992543] * X + [0.02692103]
# X:5, Y: [49.989635]
# X:2.5, Y: [25.008278]
# Y = [9.992569] * X + [0.02683003]
# X:5, Y: [49.989674]
# X:2.5, Y: [25.008253]
# Y = [9.992594] * X + [0.0267393]
# X:5, Y: [49.989708]
# X:2.5, Y: [25.008223]
# Y = [9.992619] * X + [0.02664888]
# X:5, Y: [49.989742]
# X:2.5, Y: [25.008196]
# Y = [9.992643] * X + [0.02655878]
# X:5, Y: [49.989777]
# X:2.5, Y: [25.008167]
# Y = [9.992668] * X + [0.02646901]
# X:5, Y: [49.98981]
# X:2.5, Y: [25.008139]
# Y = [9.992693] * X + [0.02637953]
# X:5, Y: [49.98984]
# X:2.5, Y: [25.00811]
# Y = [9.992718] * X + [0.02629039]
# X:5, Y: [49.98988]
# X:2.5, Y: [25.008085]
# Y = [9.992743] * X + [0.02620151]
# X:5, Y: [49.989918]
# X:2.5, Y: [25.008059]
# Y = [9.992767] * X + [0.02611291]
# X:5, Y: [49.98995]
# X:2.5, Y: [25.008032]
# Y = [9.992792] * X + [0.02602462]
# X:5, Y: [49.989983]
# X:2.5, Y: [25.008003]
# Y = [9.992817] * X + [0.02593662]
# X:5, Y: [49.99002]
# X:2.5, Y: [25.007978]
# Y = [9.992841] * X + [0.02584887]
# X:5, Y: [49.99005]
# X:2.5, Y: [25.00795]
# Y = [9.992865] * X + [0.02576146]
# X:5, Y: [49.990086]
# X:2.5, Y: [25.007923]
# Y = [9.992888] * X + [0.02567436]
# X:5, Y: [49.990116]
# X:2.5, Y: [25.007896]
# Y = [9.992912] * X + [0.02558757]
# X:5, Y: [49.99015]
# X:2.5, Y: [25.007868]
# Y = [9.992936] * X + [0.02550107]
# X:5, Y: [49.99018]
# X:2.5, Y: [25.007841]
# Y = [9.99296] * X + [0.02541488]
# X:5, Y: [49.99021]
# X:2.5, Y: [25.007814]
# Y = [9.992984] * X + [0.025329]
# X:5, Y: [49.99025]
# X:2.5, Y: [25.00779]
# Y = [9.993008] * X + [0.02524338]
# X:5, Y: [49.99028]
# X:2.5, Y: [25.007763]
# Y = [9.9930315] * X + [0.02515806]
# X:5, Y: [49.990314]
# X:2.5, Y: [25.007736]
# Y = [9.993055] * X + [0.02507301]
# X:5, Y: [49.990353]
# X:2.5, Y: [25.007711]
# Y = [9.993079] * X + [0.02498822]
# X:5, Y: [49.990387]
# X:2.5, Y: [25.007687]
# Y = [9.993102] * X + [0.02490369]
# X:5, Y: [49.990414]
# X:2.5, Y: [25.00766]
# Y = [9.993125] * X + [0.0248195]
# X:5, Y: [49.990444]
# X:2.5, Y: [25.007633]
# 900 Loss = 0.00011    W =   9.993148 B =   0.024736
# Y = [9.993148] * X + [0.02473561]
# X:5, Y: [49.990475]
# X:2.5, Y: [25.007607]
# Y = [9.993171] * X + [0.02465203]
# X:5, Y: [49.990505]
# X:2.5, Y: [25.00758]
# Y = [9.993194] * X + [0.02456876]
# X:5, Y: [49.99054]
# X:2.5, Y: [25.007553]
# Y = [9.9932165] * X + [0.02448575]
# X:5, Y: [49.99057]
# X:2.5, Y: [25.007528]
# Y = [9.993239] * X + [0.02440303]
# X:5, Y: [49.9906]
# X:2.5, Y: [25.007502]
# Y = [9.993262] * X + [0.02432062]
# X:5, Y: [49.990635]
# X:2.5, Y: [25.007477]
# Y = [9.993285] * X + [0.02423845]
# X:5, Y: [49.990665]
# X:2.5, Y: [25.007452]
# Y = [9.993308] * X + [0.02415657]
# X:5, Y: [49.9907]
# X:2.5, Y: [25.007427]
# Y = [9.993331] * X + [0.02407494]
# X:5, Y: [49.99073]
# X:2.5, Y: [25.007402]
# Y = [9.993354] * X + [0.02399359]
# X:5, Y: [49.990765]
# X:2.5, Y: [25.00738]
# Y = [9.993377] * X + [0.02391247]
# X:5, Y: [49.9908]
# X:2.5, Y: [25.007355]
# Y = [9.993399] * X + [0.02383161]
# X:5, Y: [49.990826]
# X:2.5, Y: [25.00733]
# Y = [9.993421] * X + [0.02375105]
# X:5, Y: [49.990852]
# X:2.5, Y: [25.007301]
# Y = [9.9934435] * X + [0.0236708]
# X:5, Y: [49.990887]
# X:2.5, Y: [25.007278]
# Y = [9.993465] * X + [0.02359079]
# X:5, Y: [49.990917]
# X:2.5, Y: [25.007254]
# Y = [9.993487] * X + [0.02351106]
# X:5, Y: [49.990948]
# X:2.5, Y: [25.00723]
# Y = [9.993509] * X + [0.0234316]
# X:5, Y: [49.990974]
# X:2.5, Y: [25.007204]
# Y = [9.993531] * X + [0.02335243]
# X:5, Y: [49.99101]
# X:2.5, Y: [25.00718]
# Y = [9.993553] * X + [0.0232735]
# X:5, Y: [49.99104]
# X:2.5, Y: [25.007156]
# Y = [9.993575] * X + [0.02319484]
# X:5, Y: [49.99107]
# X:2.5, Y: [25.007133]
# Y = [9.993597] * X + [0.02311645]
# X:5, Y: [49.991104]
# X:2.5, Y: [25.00711]
# Y = [9.993619] * X + [0.02303828]
# X:5, Y: [49.99113]
# X:2.5, Y: [25.007086]
# Y = [9.993641] * X + [0.02296038]
# X:5, Y: [49.991165]
# X:2.5, Y: [25.007063]
# Y = [9.993662] * X + [0.02288271]
# X:5, Y: [49.99119]
# X:2.5, Y: [25.007036]
# Y = [9.993683] * X + [0.02280534]
# X:5, Y: [49.99122]
# X:2.5, Y: [25.007013]
# Y = [9.993705] * X + [0.02272827]
# X:5, Y: [49.991253]
# X:2.5, Y: [25.00699]
# Y = [9.993726] * X + [0.02265142]
# X:5, Y: [49.99128]
# X:2.5, Y: [25.006966]
# Y = [9.993747] * X + [0.02257484]
# X:5, Y: [49.99131]
# X:2.5, Y: [25.006943]
# Y = [9.993768] * X + [0.02249853]
# X:5, Y: [49.991337]
# X:2.5, Y: [25.006918]
# Y = [9.993789] * X + [0.02242249]
# X:5, Y: [49.991367]
# X:2.5, Y: [25.006895]
# Y = [9.99381] * X + [0.02234671]
# X:5, Y: [49.991394]
# X:2.5, Y: [25.00687]
# Y = [9.993831] * X + [0.0222712]
# X:5, Y: [49.991425]
# X:2.5, Y: [25.00685]
# Y = [9.993852] * X + [0.02219593]
# X:5, Y: [49.991455]
# X:2.5, Y: [25.006824]
# Y = [9.993873] * X + [0.0221209]
# X:5, Y: [49.991486]
# X:2.5, Y: [25.006804]
# Y = [9.993894] * X + [0.02204612]
# X:5, Y: [49.991512]
# X:2.5, Y: [25.00678]
# Y = [9.993915] * X + [0.02197158]
# X:5, Y: [49.991547]
# X:2.5, Y: [25.006758]
# Y = [9.993935] * X + [0.02189727]
# X:5, Y: [49.99157]
# X:2.5, Y: [25.006733]
# Y = [9.993956] * X + [0.02182326]
# X:5, Y: [49.991604]
# X:2.5, Y: [25.006714]
# Y = [9.993976] * X + [0.02174944]
# X:5, Y: [49.991627]
# X:2.5, Y: [25.00669]
# Y = [9.993996] * X + [0.02167593]
# X:5, Y: [49.991653]
# X:2.5, Y: [25.006664]
# Y = [9.994016] * X + [0.02160268]
# X:5, Y: [49.99168]
# X:2.5, Y: [25.006641]
# Y = [9.994036] * X + [0.02152969]
# X:5, Y: [49.991707]
# X:2.5, Y: [25.006618]
# Y = [9.994056] * X + [0.02145695]
# X:5, Y: [49.991737]
# X:2.5, Y: [25.006598]
# Y = [9.994076] * X + [0.02138446]
# X:5, Y: [49.991764]
# X:2.5, Y: [25.006575]
# Y = [9.994096] * X + [0.02131221]
# X:5, Y: [49.99179]
# X:2.5, Y: [25.006552]
# Y = [9.994116] * X + [0.02124021]
# X:5, Y: [49.99182]
# X:2.5, Y: [25.00653]
# Y = [9.994136] * X + [0.02116845]
# X:5, Y: [49.991848]
# X:2.5, Y: [25.006508]
# Y = [9.994156] * X + [0.02109694]
# X:5, Y: [49.991875]
# X:2.5, Y: [25.006487]
# Y = [9.994176] * X + [0.02102566]
# X:5, Y: [49.991905]
# X:2.5, Y: [25.006466]
# Y = [9.994196] * X + [0.02095458]
# X:5, Y: [49.991932]
# X:2.5, Y: [25.006443]
# Y = [9.994216] * X + [0.02088375]
# X:5, Y: [49.991966]
# X:2.5, Y: [25.006424]
# Y = [9.994235] * X + [0.02081311]
# X:5, Y: [49.99199]
# X:2.5, Y: [25.006401]
# Y = [9.994254] * X + [0.02074275]
# X:5, Y: [49.992016]
# X:2.5, Y: [25.006378]
# Y = [9.994273] * X + [0.02067264]
# X:5, Y: [49.99204]
# X:2.5, Y: [25.006355]
# Y = [9.994293] * X + [0.0206028]
# X:5, Y: [49.99207]
# X:2.5, Y: [25.006336]
# Y = [9.994312] * X + [0.02053315]
# X:5, Y: [49.992096]
# X:2.5, Y: [25.006313]
# Y = [9.994331] * X + [0.02046374]
# X:5, Y: [49.99212]
# X:2.5, Y: [25.006292]
# Y = [9.99435] * X + [0.0203946]
# X:5, Y: [49.992146]
# X:2.5, Y: [25.006271]
# Y = [9.9943695] * X + [0.02032568]
# X:5, Y: [49.992172]
# X:2.5, Y: [25.00625]
# Y = [9.994389] * X + [0.020257]
# X:5, Y: [49.9922]
# X:2.5, Y: [25.00623]
# Y = [9.994408] * X + [0.02018855]
# X:5, Y: [49.992226]
# X:2.5, Y: [25.006208]
# Y = [9.994427] * X + [0.02012032]
# X:5, Y: [49.992252]
# X:2.5, Y: [25.006187]
# Y = [9.994446] * X + [0.02005232]
# X:5, Y: [49.992283]
# X:2.5, Y: [25.006166]
# Y = [9.994465] * X + [0.01998452]
# X:5, Y: [49.99231]
# X:2.5, Y: [25.006147]
# Y = [9.994484] * X + [0.01991692]
# X:5, Y: [49.992336]
# X:2.5, Y: [25.006126]
# Y = [9.994502] * X + [0.01984956]
# X:5, Y: [49.99236]
# X:2.5, Y: [25.006105]
# Y = [9.994521] * X + [0.01978245]
# X:5, Y: [49.99239]
# X:2.5, Y: [25.006086]
# Y = [9.994539] * X + [0.01971553]
# X:5, Y: [49.99241]
# X:2.5, Y: [25.006063]
# Y = [9.994557] * X + [0.01964887]
# X:5, Y: [49.992435]
# X:2.5, Y: [25.006042]
# Y = [9.9945755] * X + [0.01958244]
# X:5, Y: [49.99246]
# X:2.5, Y: [25.006021]
# Y = [9.994594] * X + [0.01951627]
# X:5, Y: [49.992485]
# X:2.5, Y: [25.006]
# Y = [9.994612] * X + [0.01945033]
# X:5, Y: [49.99251]
# X:2.5, Y: [25.005981]
# Y = [9.99463] * X + [0.0193846]
# X:5, Y: [49.992535]
# X:2.5, Y: [25.005959]
# Y = [9.994648] * X + [0.01931911]
# X:5, Y: [49.992558]
# X:2.5, Y: [25.00594]
# Y = [9.994666] * X + [0.01925386]
# X:5, Y: [49.992584]
# X:2.5, Y: [25.00592]
# Y = [9.994684] * X + [0.01918882]
# X:5, Y: [49.992607]
# X:2.5, Y: [25.005898]
# Y = [9.994702] * X + [0.01912401]
# X:5, Y: [49.992634]
# X:2.5, Y: [25.005878]
# Y = [9.99472] * X + [0.0190594]
# X:5, Y: [49.99266]
# X:2.5, Y: [25.005861]
# Y = [9.994739] * X + [0.01899499]
# X:5, Y: [49.992687]
# X:2.5, Y: [25.005842]
# Y = [9.994757] * X + [0.01893079]
# X:5, Y: [49.992718]
# X:2.5, Y: [25.005823]
# Y = [9.994774] * X + [0.01886675]
# X:5, Y: [49.992737]
# X:2.5, Y: [25.005802]
# Y = [9.994792] * X + [0.01880297]
# X:5, Y: [49.992764]
# X:2.5, Y: [25.005783]
# Y = [9.994809] * X + [0.0187394]
# X:5, Y: [49.992783]
# X:2.5, Y: [25.005762]
# Y = [9.994827] * X + [0.01867607]
# X:5, Y: [49.992813]
# X:2.5, Y: [25.005745]
# Y = [9.994844] * X + [0.01861291]
# X:5, Y: [49.992832]
# X:2.5, Y: [25.005724]
# Y = [9.994862] * X + [0.01854999]
# X:5, Y: [49.99286]
# X:2.5, Y: [25.005705]
# Y = [9.994879] * X + [0.01848728]
# X:5, Y: [49.99288]
# X:2.5, Y: [25.005686]
# Y = [9.994896] * X + [0.01842481]
# X:5, Y: [49.992905]
# X:2.5, Y: [25.005665]
# Y = [9.994913] * X + [0.01836255]
# X:5, Y: [49.992928]
# X:2.5, Y: [25.005644]
# Y = [9.99493] * X + [0.01830051]
# X:5, Y: [49.99295]
# X:2.5, Y: [25.005627]
# Y = [9.994947] * X + [0.0182387]
# X:5, Y: [49.992977]
# X:2.5, Y: [25.005608]
# Y = [9.994965] * X + [0.01817708]
# X:5, Y: [49.993]
# X:2.5, Y: [25.005589]
# Y = [9.994982] * X + [0.01811566]
# X:5, Y: [49.993023]
# X:2.5, Y: [25.00557]
# Y = [9.994999] * X + [0.01805444]
# X:5, Y: [49.99305]
# X:2.5, Y: [25.005552]
# Y = [9.995016] * X + [0.01799341]
# X:5, Y: [49.993076]
# X:2.5, Y: [25.005535]
# Y = [9.995033] * X + [0.01793256]
# X:5, Y: [49.9931]
# X:2.5, Y: [25.005516]
# Y = [9.99505] * X + [0.01787191]
# X:5, Y: [49.993122]
# X:2.5, Y: [25.005497]
# Y = [9.995067] * X + [0.01781145]
# X:5, Y: [49.993145]
# X:2.5, Y: [25.005478]
# Y = [9.995083] * X + [0.01775123]
# X:5, Y: [49.993164]
# X:2.5, Y: [25.005459]
# Y = [9.9951] * X + [0.01769124]
# X:5, Y: [49.993195]
# X:2.5, Y: [25.005442]
# 1000 Loss = 0.00006    W =   9.995116 B =   0.017631
# Y = [9.995116] * X + [0.0176314]
# X:5, Y: [49.993214]
# X:2.5, Y: [25.005423]
